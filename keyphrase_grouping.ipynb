# %%
import nltk, string
from nltk.corpus import stopwords, brown
from nltk.tokenize import RegexpTokenizer
from nltk.collocations import *
import codecs, os, json, glob
from bs4 import BeautifulSoup
from nltk.corpus import wordnet as wn
from pandas import DataFrame
import pandas as pd
wnlemmatizer = nltk.WordNetLemmatizer()

# %% [markdown]
# ## Baseline Algorithm: Frequency Distribution on Unigrams

# %%
#freq dist function from set of corpus tokens

def freqBigramsFromTokens(tokenList):
    #modify this list based on corpus
    punc = ['.',',', ';', '--', '(', ')', ':', '``', '\'\'', '?']
    #additional words that should be treated like stopwords after initial assessment of performance
    mod_num = ['one','two','three','four','five','first', 'second','third','fourth','fifth', \
               'could','should','would','might','must','will','can']
    #concatenate stopwords, punctuation, + special modals/numbers/cardinals list
    sw_p = nltk.corpus.stopwords.words('english') + punc + mod_num
    wnl_lemmas = [wnlemmatizer.lemmatize(word.lower()) for word in tokenList if word.lower() not in sw_p]
    fd = nltk.FreqDist(bigrams(wnl_lemmas))
    top_n = fd.items()[:50]
    top_n_vals = fd.values()[:50]
    i = 0
    print '%-20s' % 'WORD PAIR ', '%-20s' % 'BIGRAM COUNT'
    for b in top_n:
        print '%-12s' % b[0][0], '%-12s' % b[0][1], '%-16d' % top_n_vals[i]
        i=i+1

# %% [markdown]
# ### Functions Used for Reading Files from Directory, Tokenizing

# %%
#function to get string from file
def loadCorpusAsString(pathToFile):
    snippets = open(pathToFile, "r")
    text_list = snippets.readlines()
    snippets.close()
    text_string = reduce(lambda x, y: x + ' ' + y.strip('\t'), text_list)
    return text_string


#function to get string from file
def loadJsonCorpusAsString(path):
    snippets = open(path, "r")
    text_list = json.loads(snippets.readlines())
    text_string = reduce(lambda x, y: x + ' ' + y.strip('\t'), text_list)
    snippets.close()
    return text_string


#read file as unicode
def loadCorpusAsUnicodeString(path):
    rawtext = codecs.open(path,'r','utf-8').read()
    return rawtext

#tokenize into sentences
def tokenizeCorpusFromTuples(title_content_tuples):
    #tokenize into sentences
    tokenizer = RegexpTokenizer('\w+\'\w*|\S+|[\.!?,;:&-]') 
    '''
    \w+          strings of text, words
    |            OR
    [\.!?,;:&-]  leave in meaningful punctuation
    '''
    #deal with title + contents tuples
    docs = []
    for i in title_content_tuples:
        string = str(i[0]) + ' ' + str(i[1])
        docs = docs + string
    
    #tokenize into words, removing punctuation
    docs = docs.encode('iso-8859-1', 'ignore')
    tokens = tokenizer.tokenize(docs)
    #remove periods at end of strings, double commas, and weird double commas for more accurate FreqDist
    tokens_clean = [t.rstrip('.').strip('\'\'').lstrip('``') for t in tokens]
    return tokens_clean

#tokenize into sentences
def tokenizeCorpus(string):
    #tokenize into sentences
    tokenizer = RegexpTokenizer('\w+\'\w*|\S+|[\.!?,;:&-]') 
    '''
    \w+          strings of text, words
    |            OR
    [\.!?,;:&-]  leave in meaningful punctuation
    '''
    #tokenize into words, removing punctuation
    string = string.encode('iso-8859-1', 'ignore') 
    tokens = tokenizer.tokenize(string)
    #remove periods at end of strings, double commas, and weird double commas for more accurate FreqDist
    tokens_clean = [t.rstrip('.').strip('\'\'').strip(')').strip('(').lstrip('``') for t in tokens]
    return tokens_clean


def htmlToTuples(filelist):
    articles = {}
    for f in filelist:
        html = loadCorpusAsString(f)
        soup = BeautifulSoup(html)
        if soup.metadata.attrs['title'] not in articles:
            articles[soup.metadata.attrs['title']] = soup.body.contents.pop()
    return list(articles.iteritems())


#read in film review corpus
def getFreqBigramsfromFile(path):
    corpus_string = loadCorpusAsString(path)
    tokenized_corpus = tokenizeCorpus(corpus_string)
    fd = freqBigramsFromTokens(tokenized_corpus)
    return fd

#read in film review corpus
def getFreqBigramsfromCollection(file_list):
    corpus_string = concatFilesUnicode(file_list)
    tokenized_corpus = tokenizeCorpus(corpus_string)
    fd = freqBigramsFromTokens(tokenized_corpus)
    return fd

#read in film review corpus
def getFreqBigramsfromHTMLfiles(file_list):
    title_content_tuples = htmlToTuples(file_list)
    tokenized_corpus = tokenizeCorpusFromTuples(title_content_tuples)
    fd = freqBigramsFromTokens(tokenized_corpus)
    return fd

#run functions separately on documents in corpus (can I pass functions as args to functions?)
def runFunctionsOnFiles(file_list, func):
    corpus = [loadCorpusAsString(f) for f in file_list]
    for doc in corpus:
        func(doc)
        
#from list of files, return concatenated string of all their contents        
def concatFilesUnicode(file_list):
    #load each file as string into list
    corpus_list = [loadCorpusAsUnicodeString(f) for f in file_list]
    #concatenate strings into single string
    c = ''
    for s in corpus_list:
        c = c + s
    #return string of entire corpus
    return c

def concatFiles(file_list):
    #load each file as string into list
    corpus_list = [loadCorpusAsString(f) for f in file_list]
    #concatenate strings
    c = ''
    for s in corpus_list:
        c = c + s
    #return string of entire corpus
    return c

# %%
#function to get string from file
def loadJsonCorpusAsString(path):
    snippets = open(path, "r")
    text_list = snippets.readlines()
    text_string = reduce(lambda x, y: x + ' ' + y.strip('\t'), text_list)
    snippets.close()
    return text_string

# %% [markdown]
# # Step 1. Read Files from Directory into List

# %%
#get list of files
def readFilestoList(path):
    filelist = []
    for file in glob.glob(os.path.join(path, '*.json')):
        filelist.append(file)
    return filelist

# %%
def jsonToTuples(filelist):
    articles = []
    for filepath in filelist:
        with open(filepath, 'r') as f:
            j = json.load(f)
            if 'objects' in j.keys():
                if 'title' in j['objects'][0]:
                    articles.append((j['objects'][0]['title'], j['objects'][0]['text']))
    return articles

# %%
voterID = readFilestoList('data/voterID_clean/')

# %%
votID = jsonToTuples(voterID)

# %% [markdown]
# # Step 2. Read Titles and Text into Tuple List

# %% [markdown]
# # Step 3. Put Titles, Content into Dataframe & Tokenize Both

# %%
#create df for titles & content
#tokenize titles and content
def tokenizeTitlesContentToDf(tuples):
    articles = []
    titles = []
    for i in tuples:
        articles.append(i[1])
        titles.append(i[0])

    data = {'article': articles, 'title': titles}
    df = DataFrame(data)
    df['tokenized_article'] = df['article'].map(nltk.word_tokenize)
    df['tokenized_title'] = df['title'].map(nltk.word_tokenize)
    return df

# %%
# health_it_df = tokenizeTitlesContentToDf(title_content_health_it)
df_votID = tokenizeTitlesContentToDf(votID)

# %%
df_votID.head()
# Out:
#                                              article  \
# 0  This video player supports Adobe Flash Player ...
# 1  iamdalex\n2 weeks ago · Miami, FL\n#VoterID Re...
# 2  by Kira Lerner Posted on November 10, 2014 at ...
# 3  Home / The Issues / Comprehensive Database of ...
# 4  A tip comes in on an issue with the polls in t...
#
#                                                title  \
# 0  First case of voter fraud confirmed in Rio Arr...
# 1                                          Instagram
# 2  America’s Historically Shameful Election Day T...
# 3  Comprehensive Database of U.S. Voter Fraud Unc...
# 4               0600 Voter ID And The Registrar Case
#
#                                    tokenized_article  \
# 0  [This, video, player, supports, Adobe, Flash, ...
# 1  [iamdalex, 2, weeks, ago, ·, Miami, ,, FL, #, ...
# 2  [by, Kira, Lerner, Posted, on, November, 10, ,...
# 3  [Home, /, The, Issues, /, Comprehensive, Datab...
# 4  [A, tip, comes, in, on, an, issue, with, the, ...
#
#                                      tokenized_title
# 0  [First, case, of, voter, fraud, confirmed, in,...
# 1                                        [Instagram]
# 2  [America’s, Historically, Shameful, Election, ...
# 3  [Comprehensive, Database, of, U.S., Voter, Fra...
# 4       [0600, Voter, ID, And, The, Registrar, Case]

# %%
df_votID.drop_duplicates(subset='title', inplace=True)

# %%
df_votID['spanish_check'] = df_votID['tokenized_article'].map(nltk.FreqDist)

# %%
df_votID_eng = df_votID[df_votID['spanish_check'].apply(lambda r: 'los' in r)==False]

# %%
len(df_votID_eng)
# Out:
# 295

# %%
len(df_votID_eng[df_votID_eng['spanish_check'].apply(lambda r: 'los' in r)==True])
# Out:
# 0

# %%
#functions for tokenizing sentences
def listToTokens(sentenceList):
    tokenized_sents = [nltk.word_tokenize(sent.strip('(').strip(')')) for sent in sentenceList]
    return tokenized_sents

def tagTokens(tokenList):
    tagged_sents = [nltk.pos_tag(sent) for sent in tokenList]
    return tagged_sents

def tagTitle(title):
    tagged_title = [nltk.pos_tag(title)]
    return tagged_title


#functions for adding columns to df of sentence tokenized, word tokenized, and pos tagged text
def docsIntoSents(columnname, df):
    df['sent_tokenized'] = df[columnname].map(nltk.sent_tokenize)
    return df
    
def sentsIntoTokens(columnname, df):
    df['word_tokenized'] = df[columnname].map(listToTokens)
    return df
    
def tokensPOStag(columnname, df, option='article'):
    if option=='article':
        columntitle = 'pos_tagged_%s' %columnname
        df[columntitle] = df[columnname].map(tagTokens)
        return df
    else:
        columntitle = 'pos_tagged_%s' %columnname
        df[columntitle] = df[columnname].map(tagTitle)
        return df

# %%
df_votID_eng = docsIntoSents('article', df_votID_eng)
# Out:
# -c:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_votID_eng = sentsIntoTokens('sent_tokenized', df_votID_eng)
# Out:
# -c:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_votID_eng = tokensPOStag('word_tokenized', df_votID_eng)
# Out:
# -c:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_votID_eng = tokensPOStag('tokenized_title', df_votID_eng, option='title')
# Out:
# -c:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#concatenate all rows in two of the columns of a dataframe
def createCorpusMultiColumns(df, columnName1, columnname2):
    corpus = []
    for row in df[columnName1]:
        corpus.extend(row)
    for row in df[columnname2]:
        corpus.extend(row)
    return corpus

def createCorpusSingleColumn(df, columnName1):
    corpus = []
    for row in df[columnName1]:
        corpus.extend(row)
    return corpus

# %% [markdown]
# # Step 4. Concatenate Titles & Text into "Corpus" for Each Directory

# %%
# votID_corpus = createCorpusSingleColumn(df_votID_2, 'word_tokenized')

# %% [markdown]
# # Pattern-Based Collocations (Noun- & Verb-Phrase Chunking)

# %%
#look for important noun phrase patterns, either nouns preceded by Det+Adj or simply compound nouns
def parseImportantNps():
    grammar = r"""
    N-N: {<DET|CD.*>?<J*|N.*>+<N.*>} # chunk DET/Cardinal w/optional ADJ or N with proper noun
           {<NNP.*>+<NNP.*>}             # chunk solo proper nouns only
    """
    cp = nltk.RegexpParser(grammar)
    return cp, 'N-N'


#function to chunk 
def chunk(tagged, func=parseImportantNps):
    chunks = []
    leaves = []
    cp, cn = func()
    for i in tagged:
        tree = cp.parse(i)
        for subtree in tree.subtrees():
            if subtree.node == cn:
                leaflist = [leaf[0] for leaf in subtree.leaves()]
                chunks.append(subtree.leaves())
                leaves.append(' '.join(leaflist))
    return leaves
        
#show the proper nouns as strings without their tags
def getChunksAsStrings(chunk_list):
    phrases = []
    for i in chunk_list:
        phrase = ''
        for j in i:
            phrase = phrase + j[0] + ' '
        phrases.append(phrase)
    return phrases    


def freqDistChunks(preprocessed, func=1):
    chunks = chunk(preprocessed, func=func)
    chunks_only = getChunksAsStrings(chunks)
    chks = FreqDist(chunks_only)  
    if func==1:
        n_list = []
        print 'Important Noun Phrases'
        for n in chks.items():
            if n[1] > 5:
                print '%-10s' % n[0], '%-10s' % n[1]
                n_list.append(['%-10s' % n[0], '%-10s' % n[1]])
        return n_list
    elif func==2:
        p_list = []
        print 'Important Predicate Phrases'
        for p in chks.items():
            if p[1] > 5:
                print '%-10s' % p[0], '%-10s' % p[1]
                p_list.append(['%-10s' % p[0], '%-10s' % p[1]])
        return p_list

# %%
# function to add new column with tagged tokens (whether from article or title) to df
def tokensPOStag(columnname, df, option='article'):
    if option=='article':
        columntitle = 'pos_tagged_%s' %columnname
        df[columntitle] = df[columnname].map(tagTokens)
        return df
    else:
        columntitle = 'pos_tagged_%s' %columnname
        df[columntitle] = df[columnname].map(tagTitle)
        return df

def chunkColumn(columnname, df):
    columntitle = 'chunked_%s' %columnname
    df[columntitle] = df[columnname].map(chunk)
    return df

# %%
df_votID_eng.head()
# Out:
#                                              article  \
# 0  This video player supports Adobe Flash Player ...
# 1  iamdalex\n2 weeks ago · Miami, FL\n#VoterID Re...
# 2  by Kira Lerner Posted on November 10, 2014 at ...
# 3  Home / The Issues / Comprehensive Database of ...
# 4  A tip comes in on an issue with the polls in t...
#
#                                                title  \
# 0  First case of voter fraud confirmed in Rio Arr...
# 1                                          Instagram
# 2  America’s Historically Shameful Election Day T...
# 3  Comprehensive Database of U.S. Voter Fraud Unc...
# 4               0600 Voter ID And The Registrar Case
#
#                                    tokenized_article  \
# 0  [This, video, player, supports, Adobe, Flash, ...
# 1  [iamdalex, 2, weeks, ago, ·, Miami, ,, FL, #, ...
# 2  [by, Kira, Lerner, Posted, on, November, 10, ,...
# 3  [Home, /, The, Issues, /, Comprehensive, Datab...
# 4  [A, tip, comes, in, on, an, issue, with, the, ...
#
#                                      tokenized_title  \
# 0  [First, case, of, voter, fraud, confirmed, in,...
# 1                                        [Instagram]
# 2  [America’s, Historically, Shameful, Election, ...
# 3  [Comprehensive, Database, of, U.S., Voter, Fra...
# 4       [0600, Voter, ID, And, The, Registrar, Case]
#
#                                        spanish_check  \
# 0  {u'the': 22, u'to': 15, u',': 11, u'of': 11, u...
# 1  {u'#': 7, u'I': 5, u'to': 5, u'and': 4, u'the'...
# 2  {u'the': 22, u',': 16, u'in': 14, u'a': 13, u'...
# 3  {u',': 175, u'the': 127, u'of': 104, u'to': 69...
# 4  {u'in': 3, u'the': 3, u'on': 2, u'.': 1, u'A':...
#
#                                       sent_tokenized  \
# 0  [This video player supports Adobe Flash Player...
# 1  [iamdalex\n2 weeks ago · Miami, FL\n#VoterID R...
# 2  [by Kira Lerner Posted on November 10, 2014 at...
# 3  [Home / The Issues / Comprehensive Database of...
# 4  [A tip comes in on an issue with the polls in ...
#
#                                       word_tokenized  \
# 0  [[This, video, player, supports, Adobe, Flash,...
# 1  [[iamdalex, 2, weeks, ago, ·, Miami, ,, FL, #,...
# 2  [[by, Kira, Lerner, Posted, on, November, 10, ...
# 3  [[Home, /, The, Issues, /, Comprehensive, Data...
# 4  [[A, tip, comes, in, on, an, issue, with, the,...
#
#                            pos_tagged_word_tokenized  \
# 0  [[(This, DT), (video, NN), (player, NN), (supp...
# 1  [[(iamdalex, NN), (2, CD), (weeks, NNS), (ago,...
# 2  [[(by, IN), (Kira, NNP), (Lerner, NNP), (Poste...
# 3  [[(Home, NN), (/, ``), (The, DT), (Issues, NNP...
# 4  [[(A, DT), (tip, NN), (comes, VBZ), (in, IN), ...
#
#                           pos_tagged_tokenized_title
# 0  [[(First, NNP), (case, NN), (of, IN), (voter, ...
# 1                                [[(Instagram, NN)]]
# 2  [[(America’s, NNS), (Historically, RB), (Shame...
# 3  [[(Comprehensive, NNP), (Database, NNP), (of, ...
# 4  [[(0600, CD), (Voter, NNP), (ID, NNP), (And, C...

# %%
#blank articles
df_votID_eng[df_votID_eng.pos_tagged_word_tokenized.apply(lambda r: len(r[0]))==0]
# Out:
#     article                                              title  \
# 78                                    Harrison Beacher Realtor
# 117             Dianna Duran Secretary of State 2014_ Voter ID
# 292          ACLU demands secretary of state change 'illega...
# 374                    Voter-ID backer catches Dems in the act
# 436            Long-stalled voter ID legislation gets new life
#
#     tokenized_article                                    tokenized_title  \
# 78                 []                       [Harrison, Beacher, Realtor]
# 117                []  [Dianna, Duran, Secretary, of, State, 2014_, V...
# 292                []  [ACLU, demands, secretary, of, state, change, ...
# 374                []    [Voter-ID, backer, catches, Dems, in, the, act]
# 436                []  [Long-stalled, voter, ID, legislation, gets, n...
#
#     spanish_check sent_tokenized word_tokenized pos_tagged_word_tokenized  \
# 78             {}             []           [[]]                      [[]]
# 117            {}             []           [[]]                      [[]]
# 292            {}             []           [[]]                      [[]]
# 374            {}             []           [[]]                      [[]]
# 436            {}             []           [[]]                      [[]]
#
#                             pos_tagged_tokenized_title
# 78   [[(Harrison, NNP), (Beacher, NNP), (Realtor, N...
# 117  [[(Dianna, NNP), (Duran, NNP), (Secretary, NNP...
# 292  [[(ACLU, NNP), (demands, NNS), (secretary, JJ)...
# 374  [[(Voter-ID, JJ), (backer, NN), (catches, NNS)...
# 436  [[(Long-stalled, JJ), (voter, NN), (ID, NNP), ...

# %%
df_votID_eng['sent_tokenized'][0]
# Out:
# [u'This video player supports Adobe Flash Player versions 10.1 and higher.',
#  u"Download the latest version\nCreated: 11/01/2014 9:35 PM\nBy: Kristen Garcia, KOB.com\nThe first case of voter fraud in New Mexico this election has been confirmed by the Rio Arriba County Clerk's Office.",
#  u"According to the Rio Arriba County Clerk's office, a voter trying to cast an early ballot in Espanola Saturday was told he had already voted three days prior.",
#  u"The man told poll workers he hadn't voted.",
#  u"He was then shown the signature of the voter, but he says it wasn't his signature.",
#  u"Officials say they were able to confirm that the signature on the original ballot did not match the legal voter's signature on file.",
#  u'Poll workers allowed the man to vote on a provisional ballot, but election officials will have to determine whether the provisional ballot can be counted.',
#  u'Elections officials have no legal means of actually verifying signatures or confirming identification of a voter.',
#  u'"The poll workers and the Rio Arriba County Clerk\u2019s office did a good job in responding to the situation, following all the procedures available to them," said Bobbi Shearer of the Secretary of State\u2019s office Saturday, "I have nothing, but praise for their efforts to try to ensure integrity in the election.',
#  u'It is just that under current law there are no means available to poll workers to help them determine if a voter is actually the person he says he is.',
#  u'"\nShearer said the fraudulent voter\'s vote has already gone through a tabulator and cannot be identified or separated from all the legitimate ballots in the machine.',
#  u'Rio Arriba County also fell under scrutiny just two years ago when campaign workers were caught offering alchol to voters.',
#  u'If voters have any concerns or wish to report an irregularity of any kind, they are encouraged to call the Secretary of State\u2019s office: 1-800-477-3632.',
#  u'KOB welcomes a lively and courteous discussion as long as you follow the rules of conduct set forth in our Terms of Use.',
#  u'Comments are not pre-screened before they post.',
#  u'You agree that anything you post may be used, along with your name and profile picture, in accordance with our Privacy Policy and the license you have granted pursuant to our Terms of Use.']

# %%
df_votID_eng = chunkColumn('pos_tagged_word_tokenized', df_votID_eng)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# -c:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_votID_eng['article_chunks'] = df_votID_eng.pos_tagged_word_tokenized.apply(chunk)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# -c:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_votID_eng.head()
# Out:
#                                              article  \
# 0  This video player supports Adobe Flash Player ...
# 1  iamdalex\n2 weeks ago · Miami, FL\n#VoterID Re...
# 2  by Kira Lerner Posted on November 10, 2014 at ...
# 3  Home / The Issues / Comprehensive Database of ...
# 4  A tip comes in on an issue with the polls in t...
#
#                                                title  \
# 0  First case of voter fraud confirmed in Rio Arr...
# 1                                          Instagram
# 2  America’s Historically Shameful Election Day T...
# 3  Comprehensive Database of U.S. Voter Fraud Unc...
# 4               0600 Voter ID And The Registrar Case
#
#                                    tokenized_article  \
# 0  [This, video, player, supports, Adobe, Flash, ...
# 1  [iamdalex, 2, weeks, ago, ·, Miami, ,, FL, #, ...
# 2  [by, Kira, Lerner, Posted, on, November, 10, ,...
# 3  [Home, /, The, Issues, /, Comprehensive, Datab...
# 4  [A, tip, comes, in, on, an, issue, with, the, ...
#
#                                      tokenized_title  \
# 0  [First, case, of, voter, fraud, confirmed, in,...
# 1                                        [Instagram]
# 2  [America’s, Historically, Shameful, Election, ...
# 3  [Comprehensive, Database, of, U.S., Voter, Fra...
# 4       [0600, Voter, ID, And, The, Registrar, Case]
#
#                                        spanish_check  \
# 0  {u'the': 22, u'to': 15, u',': 11, u'of': 11, u...
# 1  {u'#': 7, u'I': 5, u'to': 5, u'and': 4, u'the'...
# 2  {u'the': 22, u',': 16, u'in': 14, u'a': 13, u'...
# 3  {u',': 175, u'the': 127, u'of': 104, u'to': 69...
# 4  {u'in': 3, u'the': 3, u'on': 2, u'.': 1, u'A':...
#
#                                       sent_tokenized  \
# 0  [This video player supports Adobe Flash Player...
# 1  [iamdalex\n2 weeks ago · Miami, FL\n#VoterID R...
# 2  [by Kira Lerner Posted on November 10, 2014 at...
# 3  [Home / The Issues / Comprehensive Database of...
# 4  [A tip comes in on an issue with the polls in ...
#
#                                       word_tokenized  \
# 0  [[This, video, player, supports, Adobe, Flash,...
# 1  [[iamdalex, 2, weeks, ago, ·, Miami, ,, FL, #,...
# 2  [[by, Kira, Lerner, Posted, on, November, 10, ...
# 3  [[Home, /, The, Issues, /, Comprehensive, Data...
# 4  [[A, tip, comes, in, on, an, issue, with, the,...
#
#                            pos_tagged_word_tokenized  \
# 0  [[(This, DT), (video, NN), (player, NN), (supp...
# 1  [[(iamdalex, NN), (2, CD), (weeks, NNS), (ago,...
# 2  [[(by, IN), (Kira, NNP), (Lerner, NNP), (Poste...
# 3  [[(Home, NN), (/, ``), (The, DT), (Issues, NNP...
# 4  [[(A, DT), (tip, NN), (comes, VBZ), (in, IN), ...
#
#                           pos_tagged_tokenized_title  \
# 0  [[(First, NNP), (case, NN), (of, IN), (voter, ...
# 1                                [[(Instagram, NN)]]
# 2  [[(America’s, NNS), (Historically, RB), (Shame...
# 3  [[(Comprehensive, NNP), (Database, NNP), (of, ...
# 4  [[(0600, CD), (Voter, NNP), (ID, NNP), (And, C...
#
#                    chunked_pos_tagged_word_tokenized  \
# 0  [video player supports Adobe Flash Player vers...
# 1  [VoterID Requirements, polls today, case someb...
# 2  [Kira Lerner Posted, 5:01 pm Updated, Shameful...
# 3  [Issues / Comprehensive Database, U.S. Voter, ...
# 4                 [Trevillians district, Joe checks]
#
#                                       article_chunks
# 0  [video player supports Adobe Flash Player vers...
# 1  [VoterID Requirements, polls today, case someb...
# 2  [Kira Lerner Posted, 5:01 pm Updated, Shameful...
# 3  [Issues / Comprehensive Database, U.S. Voter, ...
# 4                 [Trevillians district, Joe checks]

# %%
df_votID_eng['article_chunks'][0]
# Out:
# [u'video player supports Adobe Flash Player versions',
#  u'version Created',
#  u'9:35 PM By',
#  u'Kristen Garcia',
#  u'KOB.com The first case',
#  u'voter fraud',
#  u'New Mexico',
#  u'Rio Arriba County Clerk',
#  u'Rio Arriba County Clerk',
#  u'early ballot',
#  u'Espanola Saturday',
#  u'poll workers',
#  u'original ballot',
#  u'legal voter',
#  u'Poll workers',
#  u'provisional ballot',
#  u'election officials',
#  u'provisional ballot',
#  u'Elections officials',
#  u'legal means',
#  u'poll workers',
#  u'Rio Arriba County Clerk\u2019s office',
#  u'good job',
#  u'Bobbi Shearer',
#  u'State\u2019s office Saturday',
#  u'current law',
#  u'fraudulent voter',
#  u'legitimate ballots',
#  u'Rio Arriba County',
#  u'campaign workers',
#  u'offering alchol',
#  u'State\u2019s office',
#  u'courteous discussion',
#  u'conduct set forth',
#  u'profile picture',
#  u'Privacy Policy']

# %%
df_votID_eng.title.count(), len(df_votID_eng.title.unique())
# Out:
# (295, 295)

# %%
corpus_chunks = []
for chunk in df_votID_eng['article_chunks']:
    corpus_chunks.extend(chunk)
     
chunk_fd = nltk.FreqDist(corpus_chunks)

# %%
freqchunks = chunk_fd.keys()[:50]

# %%
freqchunks_set = set(freqchunks)

# %%
df_votID_eng.article_chunks.head()
# Out:
# 0    [video player supports Adobe Flash Player vers...
# 1    [VoterID Requirements, polls today, case someb...
# 2    [Kira Lerner Posted, 5:01 pm Updated, Shameful...
# 3    [Issues / Comprehensive Database, U.S. Voter, ...
# 4                   [Trevillians district, Joe checks]
# Name: article_chunks, dtype: object

# %%
def get_keyphrase_columns(keyphrases, indf, keyphrase_col='common_chunks'):
    df_chunks=pd.DataFrame(index=indf.index)
    df_chunks[keyphrase_col]=indf.article_chunks.apply(lambda r: set(r)&freqchunks_set)
    
    for i,v in enumerate(keyphrases):
        df_chunks[v.encode('utf8', 'ignore')]=df_chunks.common_chunks.apply(lambda r: 1 if v in r else 0)
    
    return df_chunks

# %%
def get_overlaps(keyphrases, indf, keyphrase_col='common_chunks'):
    df_chunks=get_keyphrase_columns(keyphrases, indf, keyphrase_col)
    
    print df_chunks.columns
    chunk_overlap = pd.DataFrame(index=df_chunks.columns[1:])
    
    for i,v in enumerate(keyphrases):
        v = v.encode('utf8', 'ignore')
        chunk_overlap[v]=df_chunks[df_chunks[v]==1][df_chunks.columns[1:]].sum()
    
    return chunk_overlap

# %%
chunk_overlap = get_overlaps(freqchunks, df_votID_eng)
# Out:
# Index([u'common_chunks', u'voter fraud', u'photo ID', u'voter ID laws', u'North Carolina', u'Election Day', u'Supreme Court', u'birth certificate', u'provisional ballot', u'voter ID law', u'Voting Rights Act', u'poll workers', u'voter ID', u'polling place', u'driver’s license', u'Justice Department', u'voting rights', u'GREG PALAST', u'photo identification', u'Brennan Center', u'United States', u'first time', u'minority voters', u'provisional ballots', u'election officials', u'voter suppression', u'early voting', u'new law', u'election day', u'U.S. Supreme Court', u'ID law', u'general election', u'poll worker', u'eligible voters', u'same-day registration', u'ID laws', u'federal government', u'black voters', u'midterm elections', u'other states', u'voter registration card', u'Voter ID laws', u'ballot box', u'President Obama', u'absentee ballots', u'White House', u'federal elections', u'new voter ID law', u'African Americans', u'full article', u'voter registration'], dtype='object')

# %%
chunk_overlap.head()
# Out:
#                 voter fraud  photo ID  voter ID laws  North Carolina  \
# voter fraud              74        24             24              24
# photo ID                 24        66             21              19
# voter ID laws            24        21             59              23
# North Carolina           24        19             23              59
# Election Day             24        28             18              18
#
#                 Election Day  Supreme Court  birth certificate  \
# voter fraud               24             18                  9
# photo ID                  28             16                 14
# voter ID laws             18             17                  8
# North Carolina            18             20                  7
# Election Day              63             12                 10
#
#                 provisional ballot  voter ID law  Voting Rights Act  \
# voter fraud                     14            18                 18
# photo ID                        11            19                 15
# voter ID laws                    8            16                 11
# North Carolina                  10            11                 16
# Election Day                    13            14                 11
#
#                        ...          Voter ID laws  ballot box  \
# voter fraud            ...                     11          11
# photo ID               ...                     10           8
# voter ID laws          ...                      8           7
# North Carolina         ...                      8           9
# Election Day           ...                      5           8
#
#                 President Obama  absentee ballots  White House  \
# voter fraud                   3                16            1
# photo ID                      3                 7            1
# voter ID laws                 4                 4            3
# North Carolina                9                 3            5
# Election Day                  6                 4            1
#
#                 federal elections  new voter ID law  African Americans  \
# voter fraud                     3                 6                  7
# photo ID                        4                 6                  3
# voter ID laws                   2                 8                  5
# North Carolina                  2                 8                  7
# Election Day                    3                 7                  4
#
#                 full article  voter registration
# voter fraud                1                   7
# photo ID                   3                   8
# voter ID laws              3                   5
# North Carolina             2                   5
# Election Day               1                   5
#
# [5 rows x 50 columns]

# %%
chunk_overlap.loc['photo ID']
# Out:
# voter fraud                24
# photo ID                   66
# voter ID laws              21
# North Carolina             19
# Election Day               28
# Supreme Court              16
# birth certificate          14
# provisional ballot         11
# voter ID law               19
# Voting Rights Act          15
# poll workers               16
# voter ID                   14
# polling place              14
# driver’s license           14
# Justice Department          9
# voting rights              12
# GREG PALAST                 0
# photo identification       14
# Brennan Center             11
# United States              10
# first time                 14
# minority voters            11
# provisional ballots        10
# election officials         12
# voter suppression           6
# early voting               11
# new law                     9
# election day                9
# U.S. Supreme Court         13
# ID law                     13
# general election            4
# poll worker                10
# eligible voters             9
# same-day registration       5
# ID laws                     6
# federal government          7
# black voters               10
# midterm elections           5
# other states                8
# voter registration card     8
# Voter ID laws              10
# ballot box                  8
# President Obama             3
# absentee ballots            7
# White House                 1
# federal elections           4
# new voter ID law            6
# African Americans           3
# full article                3
# voter registration          8
# Name: photo ID, dtype: int64

# %%
chunk_overlap.apply(lambda r: r/max(r), axis=1)
# Out:
#                          voter fraud  photo ID  voter ID laws  North Carolina  \
# voter fraud                 1.000000  0.324324       0.324324        0.324324
# photo ID                    0.363636  1.000000       0.318182        0.287879
# voter ID laws               0.406780  0.355932       1.000000        0.389831
# North Carolina              0.406780  0.322034       0.389831        1.000000
# Election Day                0.380952  0.444444       0.285714        0.285714
# Supreme Court               0.375000  0.333333       0.354167        0.416667
# birth certificate           0.290323  0.451613       0.258065        0.225806
# provisional ballot          0.500000  0.392857       0.285714        0.357143
# voter ID law                0.461538  0.487179       0.410256        0.282051
# Voting Rights Act           0.473684  0.394737       0.289474        0.421053
# poll workers                0.294118  0.470588       0.323529        0.294118
# voter ID                    0.394737  0.368421       0.421053        0.368421
# polling place               0.382353  0.411765       0.264706        0.264706
# driver’s license            0.461538  0.538462       0.346154        0.269231
# Justice Department          0.483871  0.290323       0.225806        0.419355
# voting rights               0.342857  0.342857       0.285714        0.428571
# GREG PALAST                 1.000000  0.000000       0.000000        1.000000
# photo identification        0.629630  0.518519       0.259259        0.370370
# Brennan Center              0.294118  0.323529       0.323529        0.441176
# United States               0.357143  0.357143       0.321429        0.357143
# first time                  0.275862  0.482759       0.310345        0.482759
# minority voters             0.370370  0.407407       0.444444        0.444444
# provisional ballots         0.571429  0.476190       0.285714        0.523810
# election officials          0.538462  0.461538       0.346154        0.346154
# voter suppression           0.347826  0.260870       0.260870        0.260870
# early voting                0.480000  0.440000       0.280000        0.440000
# new law                     0.370370  0.333333       0.222222        0.333333
# election day                0.480000  0.360000       0.160000        0.200000
# U.S. Supreme Court          0.392857  0.464286       0.357143        0.428571
# ID law                      0.458333  0.541667       0.375000        0.375000
# general election            0.555556  0.444444       0.222222        0.333333
# poll worker                 0.333333  0.555556       0.333333        0.333333
# eligible voters             0.476190  0.428571       0.428571        0.333333
# same-day registration       0.357143  0.357143       0.285714        0.428571
# ID laws                     0.578947  0.315789       0.526316        0.421053
# federal government          0.421053  0.368421       0.210526        0.473684
# black voters                0.789474  0.526316       0.368421        0.315789
# midterm elections           0.380952  0.238095       0.333333        0.523810
# other states                0.294118  0.470588       0.352941        0.411765
# voter registration card     0.333333  0.444444       0.444444        0.333333
# Voter ID laws               0.500000  0.454545       0.363636        0.363636
# ballot box                  0.550000  0.400000       0.350000        0.450000
# President Obama             0.166667  0.166667       0.222222        0.500000
# absentee ballots            1.000000  0.437500       0.250000        0.187500
# White House                 0.111111  0.111111       0.333333        0.555556
# federal elections           0.272727  0.363636       0.181818        0.181818
# new voter ID law            0.352941  0.352941       0.470588        0.470588
# African Americans           0.500000  0.214286       0.357143        0.500000
# full article                0.125000  0.375000       0.375000        0.250000
# voter registration          0.437500  0.500000       0.312500        0.312500
#
#                          Election Day  Supreme Court  birth certificate  \
# voter fraud                  0.324324       0.243243           0.121622
# photo ID                     0.424242       0.242424           0.212121
# voter ID laws                0.305085       0.288136           0.135593
# North Carolina               0.305085       0.338983           0.118644
# Election Day                 1.000000       0.190476           0.158730
# Supreme Court                0.250000       1.000000           0.270833
# birth certificate            0.322581       0.419355           1.000000
# provisional ballot           0.464286       0.321429           0.428571
# voter ID law                 0.358974       0.512821           0.307692
# Voting Rights Act            0.289474       0.605263           0.289474
# poll workers                 0.500000       0.264706           0.294118
# voter ID                     0.289474       0.342105           0.236842
# polling place                0.500000       0.176471           0.176471
# driver’s license             0.461538       0.269231           0.384615
# Justice Department           0.193548       0.258065           0.193548
# voting rights                0.428571       0.371429           0.257143
# GREG PALAST                  1.000000       0.000000           0.000000
# photo identification         0.296296       0.296296           0.370370
# Brennan Center               0.411765       0.382353           0.352941
# United States                0.250000       0.285714           0.250000
# first time                   0.586207       0.448276           0.344828
# minority voters              0.518519       0.444444           0.296296
# provisional ballots          0.476190       0.476190           0.190476
# election officials           0.461538       0.192308           0.230769
# voter suppression            0.347826       0.304348           0.130435
# early voting                 0.520000       0.400000           0.320000
# new law                      0.407407       0.370370           0.407407
# election day                 0.320000       0.320000           0.160000
# U.S. Supreme Court           0.535714       0.321429           0.285714
# ID law                       0.416667       0.541667           0.333333
# general election             0.333333       0.555556           0.222222
# poll worker                  0.333333       0.277778           0.277778
# eligible voters              0.380952       0.238095           0.238095
# same-day registration        0.428571       0.357143           0.071429
# ID laws                      0.315789       0.473684           0.368421
# federal government           0.473684       0.526316           0.263158
# black voters                 0.315789       0.263158           0.157895
# midterm elections            0.333333       0.333333           0.238095
# other states                 0.352941       0.588235           0.294118
# voter registration card      0.444444       0.500000           0.666667
# Voter ID laws                0.227273       0.363636           0.181818
# ballot box                   0.400000       0.500000           0.200000
# President Obama              0.333333       0.222222           0.055556
# absentee ballots             0.250000       0.125000           0.125000
# White House                  0.111111       0.000000           0.000000
# federal elections            0.272727       0.545455           0.454545
# new voter ID law             0.411765       0.411765           0.470588
# African Americans            0.285714       0.500000           0.285714
# full article                 0.125000       0.250000           0.250000
# voter registration           0.312500       0.437500           0.375000
#
#                          provisional ballot  voter ID law  Voting Rights Act  \
# voter fraud                        0.189189      0.243243           0.243243
# photo ID                           0.166667      0.287879           0.227273
# voter ID laws                      0.135593      0.271186           0.186441
# North Carolina                     0.169492      0.186441           0.271186
# Election Day                       0.206349      0.222222           0.174603
# Supreme Court                      0.187500      0.416667           0.479167
# birth certificate                  0.387097      0.387097           0.354839
# provisional ballot                 1.000000      0.428571           0.250000
# voter ID law                       0.307692      1.000000           0.358974
# Voting Rights Act                  0.184211      0.368421           1.000000
# poll workers                       0.411765      0.352941           0.264706
# voter ID                           0.210526      0.368421           0.157895
# polling place                      0.352941      0.294118           0.117647
# driver’s license                   0.269231      0.307692           0.230769
# Justice Department                 0.064516      0.258065           0.548387
# voting rights                      0.200000      0.228571           0.228571
# GREG PALAST                        1.000000      0.000000           0.000000
# photo identification               0.407407      0.296296           0.407407
# Brennan Center                     0.264706      0.235294           0.382353
# United States                      0.178571      0.250000           0.214286
# first time                         0.310345      0.275862           0.413793
# minority voters                    0.185185      0.481481           0.370370
# provisional ballots                0.523810      0.333333           0.238095
# election officials                 0.307692      0.269231           0.230769
# voter suppression                  0.130435      0.173913           0.391304
# early voting                       0.320000      0.280000           0.360000
# new law                            0.333333      0.444444           0.296296
# election day                       0.200000      0.200000           0.520000
# U.S. Supreme Court                 0.214286      0.392857           0.428571
# ID law                             0.333333      0.541667           0.250000
# general election                   0.222222      0.444444           0.222222
# poll worker                        0.388889      0.444444           0.388889
# eligible voters                    0.142857      0.238095           0.238095
# same-day registration              0.214286      0.142857           0.214286
# ID laws                            0.263158      0.526316           0.263158
# federal government                 0.210526      0.315789           0.473684
# black voters                       0.210526      0.210526           0.578947
# midterm elections                  0.238095      0.238095           0.142857
# other states                       0.176471      0.529412           0.411765
# voter registration card            0.333333      0.500000           0.444444
# Voter ID laws                      0.136364      0.227273           0.136364
# ballot box                         0.200000      0.400000           0.450000
# President Obama                    0.111111      0.055556           0.166667
# absentee ballots                   0.125000      0.250000           0.500000
# White House                        0.000000      0.000000           0.000000
# federal elections                  0.181818      0.272727           0.454545
# new voter ID law                   0.352941      0.352941           0.470588
# African Americans                  0.285714      0.285714           0.428571
# full article                       0.250000      0.250000           0.125000
# voter registration                 0.250000      0.375000           0.375000
#
#                                 ...          Voter ID laws  ballot box  \
# voter fraud                     ...               0.148649    0.148649
# photo ID                        ...               0.151515    0.121212
# voter ID laws                   ...               0.135593    0.118644
# North Carolina                  ...               0.135593    0.152542
# Election Day                    ...               0.079365    0.126984
# Supreme Court                   ...               0.166667    0.208333
# birth certificate               ...               0.129032    0.129032
# provisional ballot              ...               0.107143    0.142857
# voter ID law                    ...               0.128205    0.205128
# Voting Rights Act               ...               0.078947    0.236842
# poll workers                    ...               0.117647    0.088235
# voter ID                        ...               0.184211    0.263158
# polling place                   ...               0.147059    0.117647
# driver’s license                ...               0.192308    0.115385
# Justice Department              ...               0.064516    0.161290
# voting rights                   ...               0.085714    0.114286
# GREG PALAST                     ...               0.000000    0.000000
# photo identification            ...               0.037037    0.074074
# Brennan Center                  ...               0.058824    0.058824
# United States                   ...               0.035714    0.071429
# first time                      ...               0.034483    0.172414
# minority voters                 ...               0.074074    0.222222
# provisional ballots             ...               0.047619    0.190476
# election officials              ...               0.038462    0.115385
# voter suppression               ...               0.130435    0.086957
# early voting                    ...               0.120000    0.120000
# new law                         ...               0.000000    0.111111
# election day                    ...               0.040000    0.120000
# U.S. Supreme Court              ...               0.035714    0.214286
# ID law                          ...               0.166667    0.208333
# general election                ...               0.111111    0.222222
# poll worker                     ...               0.222222    0.222222
# eligible voters                 ...               0.190476    0.285714
# same-day registration           ...               0.000000    0.000000
# ID laws                         ...               0.210526    0.368421
# federal government              ...               0.105263    0.052632
# black voters                    ...               0.210526    0.263158
# midterm elections               ...               0.047619    0.095238
# other states                    ...               0.117647    0.117647
# voter registration card         ...               0.111111    0.222222
# Voter ID laws                   ...               1.000000    0.181818
# ballot box                      ...               0.200000    1.000000
# President Obama                 ...               0.111111    0.055556
# absentee ballots                ...               0.062500    0.125000
# White House                     ...               0.000000    0.111111
# federal elections               ...               0.000000    0.181818
# new voter ID law                ...               0.058824    0.058824
# African Americans               ...               0.071429    0.428571
# full article                    ...               0.250000    0.000000
# voter registration              ...               0.000000    0.187500
#
#                          President Obama  absentee ballots  White House  \
# voter fraud                     0.040541          0.216216     0.013514
# photo ID                        0.045455          0.106061     0.015152
# voter ID laws                   0.067797          0.067797     0.050847
# North Carolina                  0.152542          0.050847     0.084746
# Election Day                    0.095238          0.063492     0.015873
# Supreme Court                   0.083333          0.041667     0.000000
# birth certificate               0.032258          0.064516     0.000000
# provisional ballot              0.071429          0.071429     0.000000
# voter ID law                    0.025641          0.102564     0.000000
# Voting Rights Act               0.078947          0.210526     0.000000
# poll workers                    0.058824          0.088235     0.000000
# voter ID                        0.052632          0.105263     0.000000
# polling place                   0.088235          0.058824     0.029412
# driver’s license                0.076923          0.076923     0.000000
# Justice Department              0.161290          0.290323     0.032258
# voting rights                   0.085714          0.057143     0.000000
# GREG PALAST                     1.000000          0.000000     0.000000
# photo identification            0.037037          0.333333     0.037037
# Brennan Center                  0.029412          0.088235     0.000000
# United States                   0.142857          0.071429     0.035714
# first time                      0.103448          0.068966     0.034483
# minority voters                 0.074074          0.074074     0.000000
# provisional ballots             0.095238          0.142857     0.000000
# election officials              0.000000          0.230769     0.000000
# voter suppression               0.130435          0.173913     0.000000
# early voting                    0.120000          0.120000     0.000000
# new law                         0.037037          0.111111     0.037037
# election day                    0.040000          0.280000     0.040000
# U.S. Supreme Court              0.142857          0.071429     0.000000
# ID law                          0.041667          0.166667     0.000000
# general election                0.000000          0.333333     0.000000
# poll worker                     0.055556          0.055556     0.000000
# eligible voters                 0.095238          0.047619     0.000000
# same-day registration           0.071429          0.142857     0.000000
# ID laws                         0.105263          0.105263     0.052632
# federal government              0.210526          0.105263     0.052632
# black voters                    0.157895          0.368421     0.000000
# midterm elections               0.190476          0.000000     0.142857
# other states                    0.000000          0.058824     0.000000
# voter registration card         0.055556          0.111111     0.000000
# Voter ID laws                   0.090909          0.045455     0.000000
# ballot box                      0.050000          0.100000     0.050000
# President Obama                 1.000000          0.000000     0.111111
# absentee ballots                0.000000          1.000000     0.000000
# White House                     0.222222          0.000000     1.000000
# federal elections               0.090909          0.090909     0.000000
# new voter ID law                0.176471          0.058824     0.000000
# African Americans               0.214286          0.071429     0.071429
# full article                    0.000000          0.125000     0.000000
# voter registration              0.062500          0.062500     0.000000
#
#                          federal elections  new voter ID law  \
# voter fraud                       0.040541          0.081081
# photo ID                          0.060606          0.090909
# voter ID laws                     0.033898          0.135593
# North Carolina                    0.033898          0.135593
# Election Day                      0.047619          0.111111
# Supreme Court                     0.125000          0.145833
# birth certificate                 0.161290          0.258065
# provisional ballot                0.071429          0.214286
# voter ID law                      0.076923          0.153846
# Voting Rights Act                 0.131579          0.210526
# poll workers                      0.088235          0.205882
# voter ID                          0.052632          0.052632
# polling place                     0.058824          0.147059
# driver’s license                  0.115385          0.115385
# Justice Department                0.096774          0.129032
# voting rights                     0.085714          0.114286
# GREG PALAST                       0.000000          1.000000
# photo identification              0.074074          0.185185
# Brennan Center                    0.058824          0.205882
# United States                     0.107143          0.142857
# first time                        0.103448          0.310345
# minority voters                   0.111111          0.185185
# provisional ballots               0.047619          0.285714
# election officials                0.038462          0.153846
# voter suppression                 0.043478          0.086957
# early voting                      0.120000          0.160000
# new law                           0.074074          0.259259
# election day                      0.120000          0.160000
# U.S. Supreme Court                0.142857          0.142857
# ID law                            0.083333          0.208333
# general election                  0.111111          0.111111
# poll worker                       0.055556          0.166667
# eligible voters                   0.000000          0.142857
# same-day registration             0.142857          0.142857
# ID laws                           0.000000          0.052632
# federal government                0.157895          0.210526
# black voters                      0.000000          0.210526
# midterm elections                 0.000000          0.190476
# other states                      0.117647          0.294118
# voter registration card           0.111111          0.388889
# Voter ID laws                     0.000000          0.045455
# ballot box                        0.100000          0.050000
# President Obama                   0.055556          0.166667
# absentee ballots                  0.062500          0.062500
# White House                       0.000000          0.000000
# federal elections                 1.000000          0.181818
# new voter ID law                  0.117647          1.000000
# African Americans                 0.071429          0.214286
# full article                      0.250000          0.250000
# voter registration                0.125000          0.187500
#
#                          African Americans  full article  voter registration
# voter fraud                       0.094595      0.013514            0.094595
# photo ID                          0.045455      0.045455            0.121212
# voter ID laws                     0.084746      0.050847            0.084746
# North Carolina                    0.118644      0.033898            0.084746
# Election Day                      0.063492      0.015873            0.079365
# Supreme Court                     0.145833      0.041667            0.145833
# birth certificate                 0.129032      0.064516            0.193548
# provisional ballot                0.142857      0.071429            0.142857
# voter ID law                      0.102564      0.051282            0.153846
# Voting Rights Act                 0.157895      0.026316            0.157895
# poll workers                      0.088235      0.029412            0.176471
# voter ID                          0.131579      0.026316            0.078947
# polling place                     0.058824      0.058824            0.205882
# driver’s license                  0.076923      0.038462            0.192308
# Justice Department                0.129032      0.032258            0.096774
# voting rights                     0.200000      0.028571            0.200000
# GREG PALAST                       1.000000      0.000000            0.000000
# photo identification              0.111111      0.037037            0.185185
# Brennan Center                    0.029412      0.029412            0.117647
# United States                     0.107143      0.000000            0.214286
# first time                        0.206897      0.034483            0.172414
# minority voters                   0.148148      0.037037            0.148148
# provisional ballots               0.190476      0.142857            0.190476
# election officials                0.038462      0.038462            0.115385
# voter suppression                 0.130435      0.000000            0.130435
# early voting                      0.120000      0.040000            0.040000
# new law                           0.185185      0.037037            0.074074
# election day                      0.120000      0.040000            0.120000
# U.S. Supreme Court                0.107143      0.035714            0.178571
# ID law                            0.166667      0.083333            0.166667
# general election                  0.222222      0.111111            0.111111
# poll worker                       0.055556      0.111111            0.111111
# eligible voters                   0.142857      0.000000            0.095238
# same-day registration             0.142857      0.071429            0.214286
# ID laws                           0.263158      0.000000            0.157895
# federal government                0.052632      0.105263            0.157895
# black voters                      0.263158      0.000000            0.105263
# midterm elections                 0.190476      0.000000            0.095238
# other states                      0.058824      0.117647            0.117647
# voter registration card           0.222222      0.055556            0.277778
# Voter ID laws                     0.045455      0.090909            0.000000
# ballot box                        0.300000      0.000000            0.150000
# President Obama                   0.166667      0.000000            0.055556
# absentee ballots                  0.062500      0.062500            0.062500
# White House                       0.111111      0.000000            0.000000
# federal elections                 0.090909      0.181818            0.181818
# new voter ID law                  0.176471      0.117647            0.176471
# African Americans                 1.000000      0.071429            0.285714
# full article                      0.125000      1.000000            0.000000
# voter registration                0.250000      0.000000            1.000000
#
# [50 rows x 50 columns]

# %%
chunk_overlap[['Election Day']].loc['voter fraud'][0]
# Out:
# 24

# %%
overlap_freqs=chunk_overlap.apply(lambda r: r/max(r), axis=1)

# %%
relationships = []
for i, c1 in enumerate(overlap_freqs.columns):
    for c2 in overlap_freqs.columns[i:]:
        if c1==c2:
            continue
        val=(c1,c2,overlap_freqs.loc[c1][[c2]][0], overlap_freqs.loc[c2][[c1]][0])
        
        relationships.append(val)

# %%
relationships.sort(key=lambda r: min([r[2], r[3]]), reverse=True)

# %%
relationships
# Out:
# [('Supreme Court',
#   'Voting Rights Act',
#   0.47916666666666669,
#   0.60526315789473684),
#  ('first time', 'new law', 0.44827586206896552, 0.48148148148148145),
#  ('Voting Rights Act',
#   'Justice Department',
#   0.44736842105263158,
#   0.54838709677419351),
#  ('Brennan Center', 'first time', 0.44117647058823528, 0.51724137931034486),
#  ('photo ID', 'Election Day', 0.42424242424242425, 0.44444444444444442),
#  ('Supreme Court', 'voter ID law', 0.41666666666666669, 0.51282051282051277),
#  ('provisional ballot', 'poll workers', 0.5, 0.41176470588235292),
#  ('poll workers', 'polling place', 0.41176470588235292, 0.41176470588235292),
#  ('photo identification', 'election day', 0.40740740740740738, 0.44),
#  ('provisional ballot',
#   'photo identification',
#   0.39285714285714285,
#   0.40740740740740738),
#  ('provisional ballot',
#   'provisional ballots',
#   0.39285714285714285,
#   0.52380952380952384),
#  ('voter ID laws', 'North Carolina', 0.38983050847457629, 0.38983050847457629),
#  ('voter registration card',
#   'new voter ID law',
#   0.3888888888888889,
#   0.41176470588235292),
#  ('birth certificate',
#   'provisional ballot',
#   0.38709677419354838,
#   0.42857142857142855),
#  ('birth certificate',
#   'voter registration card',
#   0.38709677419354838,
#   0.66666666666666663),
#  ('driver\xe2\x80\x99s license',
#   'early voting',
#   0.38461538461538464,
#   0.40000000000000002),
#  ('minority voters', 'new law', 0.37037037037037035, 0.37037037037037035),
#  ('federal government',
#   'other states',
#   0.36842105263157893,
#   0.41176470588235292),
#  ('black voters', 'absentee ballots', 0.36842105263157893, 0.4375),
#  ('provisional ballots',
#   'early voting',
#   0.42857142857142855,
#   0.35999999999999999),
#  ('voter ID law',
#   'Voting Rights Act',
#   0.35897435897435898,
#   0.36842105263157893),
#  ('voter ID law', 'voter ID', 0.35897435897435898, 0.36842105263157893),
#  ('minority voters',
#   'U.S. Supreme Court',
#   0.37037037037037035,
#   0.35714285714285715),
#  ('election officials',
#   'U.S. Supreme Court',
#   0.38461538461538464,
#   0.35714285714285715),
#  ('birth certificate', 'new law', 0.35483870967741937, 0.40740740740740738),
#  ('birth certificate',
#   'Brennan Center',
#   0.38709677419354838,
#   0.35294117647058826),
#  ('provisional ballot',
#   'polling place',
#   0.42857142857142855,
#   0.35294117647058826),
#  ('poll workers',
#   'election officials',
#   0.35294117647058826,
#   0.46153846153846156),
#  ('ID laws', 'ballot box', 0.36842105263157893, 0.34999999999999998),
#  ('first time',
#   'voter registration card',
#   0.34482758620689657,
#   0.55555555555555558),
#  ('Voting Rights Act',
#   'Brennan Center',
#   0.34210526315789475,
#   0.38235294117647056),
#  ('Voting Rights Act',
#   'election day',
#   0.34210526315789475,
#   0.52000000000000002),
#  ('North Carolina', 'Supreme Court', 0.33898305084745761, 0.41666666666666669),
#  ('voter ID law', 'minority voters', 0.33333333333333331, 0.48148148148148145),
#  ('voter ID law', 'ID law', 0.33333333333333331, 0.54166666666666663),
#  ('photo identification',
#   'early voting',
#   0.33333333333333331,
#   0.35999999999999999),
#  ('photo identification', 'new law', 0.33333333333333331, 0.33333333333333331),
#  ('photo identification',
#   'black voters',
#   0.33333333333333331,
#   0.47368421052631576),
#  ('photo identification', 'absentee ballots', 0.33333333333333331, 0.5625),
#  ('provisional ballots', 'ID law', 0.38095238095238093, 0.33333333333333331),
#  ('eligible voters', 'black voters', 0.33333333333333331, 0.36842105263157893),
#  ('voter fraud', 'photo ID', 0.32432432432432434, 0.36363636363636365),
#  ('voter fraud', 'voter ID laws', 0.32432432432432434, 0.40677966101694918),
#  ('voter fraud', 'North Carolina', 0.32432432432432434, 0.40677966101694918),
#  ('voter fraud', 'Election Day', 0.32432432432432434, 0.38095238095238093),
#  ('poll workers',
#   'driver\xe2\x80\x99s license',
#   0.3235294117647059,
#   0.42307692307692307),
#  ('poll workers', 'Brennan Center', 0.3235294117647059, 0.3235294117647059),
#  ('poll workers', 'early voting', 0.3235294117647059, 0.44),
#  ('poll workers',
#   'voter registration card',
#   0.3235294117647059,
#   0.61111111111111116),
#  ('Brennan Center',
#   'election officials',
#   0.3235294117647059,
#   0.42307692307692307),
#  ('Brennan Center', 'early voting', 0.3235294117647059, 0.44),
#  ('birth certificate',
#   'driver\xe2\x80\x99s license',
#   0.32258064516129031,
#   0.38461538461538464),
#  ('birth certificate',
#   'photo identification',
#   0.32258064516129031,
#   0.37037037037037035),
#  ('birth certificate', 'first time', 0.32258064516129031, 0.34482758620689657),
#  ('Justice Department',
#   'black voters',
#   0.32258064516129031,
#   0.52631578947368418),
#  ('provisional ballot', 'new law', 0.32142857142857145, 0.33333333333333331),
#  ('election day', 'black voters', 0.32000000000000001, 0.42105263157894735),
#  ('photo ID', 'voter ID laws', 0.31818181818181818, 0.3559322033898305),
#  ('Voting Rights Act', 'first time', 0.31578947368421051, 0.41379310344827586),
#  ('Voting Rights Act',
#   'U.S. Supreme Court',
#   0.31578947368421051,
#   0.42857142857142855),
#  ('voter ID', 'voting rights', 0.31578947368421051, 0.34285714285714286),
#  ('voting rights', 'Brennan Center', 0.31428571428571428, 0.3235294117647059),
#  ('provisional ballot',
#   'first time',
#   0.32142857142857145,
#   0.31034482758620691),
#  ('first time', 'new voter ID law', 0.31034482758620691, 0.52941176470588236),
#  ('birth certificate',
#   'voter ID law',
#   0.38709677419354838,
#   0.30769230769230771),
#  ('provisional ballot',
#   'voter ID law',
#   0.42857142857142855,
#   0.30769230769230771),
#  ('voter ID law', 'poll workers', 0.30769230769230771, 0.35294117647058826),
#  ('voter ID law', 'new law', 0.30769230769230771, 0.44444444444444442),
#  ('driver\xe2\x80\x99s license',
#   'poll worker',
#   0.30769230769230771,
#   0.44444444444444442),
#  ('provisional ballots',
#   'election officials',
#   0.38095238095238093,
#   0.30769230769230771),
#  ('ballot box', 'African Americans', 0.29999999999999999, 0.42857142857142855),
#  ('photo identification',
#   'provisional ballots',
#   0.29629629629629628,
#   0.38095238095238093),
#  ('minority voters',
#   'eligible voters',
#   0.29629629629629628,
#   0.38095238095238093),
#  ('minority voters',
#   'federal government',
#   0.29629629629629628,
#   0.42105263157894735),
#  ('minority voters',
#   'voter registration card',
#   0.29629629629629628,
#   0.44444444444444442),
#  ('new law', 'ID law', 0.29629629629629628, 0.33333333333333331),
#  ('new law', 'other states', 0.29629629629629628, 0.47058823529411764),
#  ('birth certificate',
#   'poll workers',
#   0.32258064516129031,
#   0.29411764705882354),
#  ('poll workers',
#   'provisional ballots',
#   0.29411764705882354,
#   0.47619047619047616),
#  ('poll workers', 'poll worker', 0.29411764705882354, 0.55555555555555558),
#  ('Brennan Center',
#   'provisional ballots',
#   0.29411764705882354,
#   0.47619047619047616),
#  ('Brennan Center',
#   'U.S. Supreme Court',
#   0.29411764705882354,
#   0.35714285714285715),
#  ('other states',
#   'new voter ID law',
#   0.29411764705882354,
#   0.29411764705882354),
#  ('ID law', 'ID laws', 0.29166666666666669, 0.36842105263157893),
#  ('Justice Department', 'absentee ballots', 0.29032258064516131, 0.5625),
#  ('birth certificate',
#   'Voting Rights Act',
#   0.35483870967741937,
#   0.28947368421052633),
#  ('Voting Rights Act',
#   'photo identification',
#   0.28947368421052633,
#   0.40740740740740738),
#  ('Voting Rights Act',
#   'black voters',
#   0.28947368421052633,
#   0.57894736842105265),
#  ('voter ID', 'Brennan Center', 0.28947368421052633, 0.3235294117647059),
#  ('voter ID', 'ID law', 0.28947368421052633, 0.45833333333333331),
#  ('voter ID laws', 'Supreme Court', 0.28813559322033899, 0.35416666666666669),
#  ('photo ID', 'North Carolina', 0.2878787878787879, 0.32203389830508472),
#  ('photo ID', 'voter ID law', 0.2878787878787879, 0.48717948717948717),
#  ('voter ID laws', 'Election Day', 0.30508474576271188, 0.2857142857142857),
#  ('North Carolina', 'Election Day', 0.30508474576271188, 0.2857142857142857),
#  ('provisional ballot',
#   'election officials',
#   0.2857142857142857,
#   0.30769230769230771),
#  ('provisional ballot',
#   'early voting',
#   0.2857142857142857,
#   0.32000000000000001),
#  ('provisional ballot', 'ID law', 0.2857142857142857, 0.33333333333333331),
#  ('provisional ballots',
#   'voter registration card',
#   0.2857142857142857,
#   0.33333333333333331),
#  ('provisional ballots',
#   'new voter ID law',
#   0.2857142857142857,
#   0.35294117647058826),
#  ('eligible voters', 'ballot box', 0.2857142857142857, 0.29999999999999999),
#  ('voter ID law',
#   'U.S. Supreme Court',
#   0.28205128205128205,
#   0.39285714285714285),
#  ('voter suppression',
#   'election day',
#   0.30434782608695654,
#   0.28000000000000003),
#  ('early voting', 'ID law', 0.28000000000000003, 0.29166666666666669),
#  ('election day', 'absentee ballots', 0.28000000000000003, 0.4375),
#  ('voter registration card',
#   'voter registration',
#   0.27777777777777779,
#   0.3125),
#  ('driver\xe2\x80\x99s license',
#   'first time',
#   0.30769230769230771,
#   0.27586206896551724),
#  ('photo identification',
#   'first time',
#   0.29629629629629628,
#   0.27586206896551724),
#  ('first time', 'minority voters', 0.27586206896551724, 0.29629629629629628),
#  ('first time',
#   'provisional ballots',
#   0.27586206896551724,
#   0.38095238095238093),
#  ('first time', 'early voting', 0.27586206896551724, 0.32000000000000001),
#  ('first time', 'U.S. Supreme Court', 0.27586206896551724, 0.2857142857142857),
#  ('first time', 'ID law', 0.27586206896551724, 0.33333333333333331),
#  ('voter ID laws', 'voter ID law', 0.2711864406779661, 0.41025641025641024),
#  ('voter ID laws', 'voter ID', 0.2711864406779661, 0.42105263157894735),
#  ('North Carolina',
#   'Voting Rights Act',
#   0.2711864406779661,
#   0.42105263157894735),
#  ('Supreme Court',
#   'birth certificate',
#   0.27083333333333331,
#   0.41935483870967744),
#  ('Supreme Court', 'voter ID', 0.27083333333333331, 0.34210526315789475),
#  ('Supreme Court', 'voting rights', 0.27083333333333331, 0.37142857142857144),
#  ('Supreme Court', 'Brennan Center', 0.27083333333333331, 0.38235294117647056),
#  ('Supreme Court', 'first time', 0.27083333333333331, 0.44827586206896552),
#  ('Supreme Court', 'ID law', 0.27083333333333331, 0.54166666666666663),
#  ('Election Day', 'poll workers', 0.26984126984126983, 0.5),
#  ('Election Day', 'polling place', 0.26984126984126983, 0.5),
#  ('Election Day', 'first time', 0.26984126984126983, 0.58620689655172409),
#  ('driver\xe2\x80\x99s license',
#   'voter registration card',
#   0.26923076923076922,
#   0.3888888888888889),
#  ('provisional ballot',
#   'Brennan Center',
#   0.32142857142857145,
#   0.26470588235294118),
#  ('poll workers', 'first time', 0.26470588235294118, 0.31034482758620691),
#  ('poll workers',
#   'U.S. Supreme Court',
#   0.26470588235294118,
#   0.32142857142857145),
#  ('poll workers', 'ID law', 0.26470588235294118, 0.375),
#  ('polling place',
#   'driver\xe2\x80\x99s license',
#   0.26470588235294118,
#   0.34615384615384615),
#  ('polling place', 'first time', 0.26470588235294118, 0.31034482758620691),
#  ('polling place', 'ID law', 0.26470588235294118, 0.375),
#  ('photo identification',
#   'Brennan Center',
#   0.33333333333333331,
#   0.26470588235294118),
#  ('Brennan Center', 'new law', 0.26470588235294118, 0.33333333333333331),
#  ('Brennan Center',
#   'same-day registration',
#   0.26470588235294118,
#   0.6428571428571429),
#  ('Voting Rights Act',
#   'minority voters',
#   0.26315789473684209,
#   0.37037037037037035),
#  ('voter ID', 'ballot box', 0.26315789473684209, 0.5),
#  ('ID laws',
#   'voter registration card',
#   0.26315789473684209,
#   0.27777777777777779),
#  ('ID laws', 'African Americans', 0.26315789473684209, 0.35714285714285715),
#  ('black voters',
#   'African Americans',
#   0.26315789473684209,
#   0.35714285714285715),
#  ('photo identification',
#   'minority voters',
#   0.25925925925925924,
#   0.25925925925925924),
#  ('new law', 'federal government', 0.25925925925925924, 0.36842105263157893),
#  ('new law', 'new voter ID law', 0.25925925925925924, 0.41176470588235292),
#  ('birth certificate',
#   'minority voters',
#   0.25806451612903225,
#   0.29629629629629628),
#  ('birth certificate',
#   'early voting',
#   0.25806451612903225,
#   0.32000000000000001),
#  ('birth certificate',
#   'U.S. Supreme Court',
#   0.25806451612903225,
#   0.2857142857142857),
#  ('birth certificate', 'ID law', 0.25806451612903225, 0.33333333333333331),
#  ('birth certificate',
#   'new voter ID law',
#   0.25806451612903225,
#   0.47058823529411764),
#  ('Justice Department',
#   'photo identification',
#   0.25806451612903225,
#   0.29629629629629628),
#  ('Justice Department',
#   'minority voters',
#   0.25806451612903225,
#   0.29629629629629628),
#  ('Justice Department',
#   'election day',
#   0.25806451612903225,
#   0.32000000000000001),
#  ('birth certificate',
#   'voting rights',
#   0.29032258064516131,
#   0.25714285714285712),
#  ('voting rights', 'ID law', 0.25714285714285712, 0.375),
#  ('voter ID law', 'polling place', 0.25641025641025639, 0.29411764705882354),
#  ('voter ID law', 'ID laws', 0.25641025641025639, 0.52631578947368418),
#  ('North Carolina', 'voting rights', 0.25423728813559321, 0.42857142857142855),
#  ('North Carolina',
#   'Brennan Center',
#   0.25423728813559321,
#   0.44117647058823528),
#  ('Supreme Court', 'minority voters', 0.25, 0.44444444444444442),
#  ('provisional ballot',
#   'driver\xe2\x80\x99s license',
#   0.25,
#   0.26923076923076922),
#  ('provisional ballot', 'poll worker', 0.25, 0.3888888888888889),
#  ('driver\xe2\x80\x99s license',
#   'U.S. Supreme Court',
#   0.26923076923076922,
#   0.25),
#  ('United States', 'new law', 0.25, 0.25925925925925924),
#  ('ID law', 'voter registration card', 0.25, 0.33333333333333331),
#  ('black voters', 'ballot box', 0.26315789473684209, 0.25),
#  ('African Americans', 'voter registration', 0.2857142857142857, 0.25),
#  ('voter fraud', 'Supreme Court', 0.24324324324324326, 0.375),
#  ('voter fraud', 'voter ID law', 0.24324324324324326, 0.46153846153846156),
#  ('voter fraud',
#   'Voting Rights Act',
#   0.24324324324324326,
#   0.47368421052631576),
#  ('photo ID', 'Supreme Court', 0.24242424242424243, 0.33333333333333331),
#  ('photo ID', 'poll workers', 0.24242424242424243, 0.47058823529411764),
#  ('first time', 'election officials', 0.2413793103448276, 0.26923076923076922),
#  ('first time', 'federal government', 0.2413793103448276, 0.36842105263157893),
#  ('early voting',
#   'voter registration card',
#   0.23999999999999999,
#   0.33333333333333331),
#  ('Election Day', 'voting rights', 0.23809523809523808, 0.42857142857142855),
#  ('Election Day',
#   'U.S. Supreme Court',
#   0.23809523809523808,
#   0.5357142857142857),
#  ('provisional ballots',
#   'same-day registration',
#   0.23809523809523808,
#   0.35714285714285715),
#  ('provisional ballots',
#   'midterm elections',
#   0.23809523809523808,
#   0.23809523809523808),
#  ('black voters',
#   'midterm elections',
#   0.26315789473684209,
#   0.23809523809523808),
#  ('North Carolina', 'voter ID', 0.23728813559322035, 0.36842105263157893),
#  ('North Carolina', 'first time', 0.23728813559322035, 0.48275862068965519),
#  ('birth certificate', 'voter ID', 0.29032258064516131, 0.23684210526315788),
#  ('Voting Rights Act',
#   'poll workers',
#   0.23684210526315788,
#   0.26470588235294118),
#  ('Voting Rights Act',
#   'voter suppression',
#   0.23684210526315788,
#   0.39130434782608697),
#  ('Voting Rights Act',
#   'early voting',
#   0.23684210526315788,
#   0.35999999999999999),
#  ('Voting Rights Act',
#   'federal government',
#   0.23684210526315788,
#   0.47368421052631576),
#  ('Voting Rights Act', 'ballot box', 0.23684210526315788, 0.45000000000000001),
#  ('voter ID', 'polling place', 0.23684210526315788, 0.26470588235294118),
#  ('voter ID', 'minority voters', 0.23684210526315788, 0.33333333333333331),
#  ('poll workers',
#   'photo identification',
#   0.23529411764705882,
#   0.29629629629629628),
#  ('poll workers', 'minority voters', 0.23529411764705882, 0.29629629629629628),
#  ('polling place',
#   'photo identification',
#   0.23529411764705882,
#   0.29629629629629628),
#  ('polling place', 'election day', 0.23529411764705882, 0.32000000000000001),
#  ('polling place', 'poll worker', 0.23529411764705882, 0.44444444444444442),
#  ('Brennan Center',
#   'minority voters',
#   0.23529411764705882,
#   0.29629629629629628),
#  ('Brennan Center',
#   'voter registration card',
#   0.23529411764705882,
#   0.44444444444444442),
#  ('voter ID law', 'other states', 0.23076923076923078, 0.52941176470588236),
#  ('voter ID law', 'voter registration card', 0.23076923076923078, 0.5),
#  ('driver\xe2\x80\x99s license',
#   'ID laws',
#   0.23076923076923078,
#   0.31578947368421051),
#  ('election officials',
#   'voter registration card',
#   0.23076923076923078,
#   0.33333333333333331),
#  ('election officials', 'absentee ballots', 0.23076923076923078, 0.375),
#  ('voter fraud',
#   'photo identification',
#   0.22972972972972974,
#   0.62962962962962965),
#  ('voting rights', 'United States', 0.22857142857142856, 0.2857142857142857),
#  ('voting rights', 'first time', 0.22857142857142856, 0.27586206896551724),
#  ('photo ID', 'Voting Rights Act', 0.22727272727272727, 0.39473684210526316),
#  ('birth certificate', 'United States', 0.22580645161290322, 0.25),
#  ('birth certificate', 'ID laws', 0.22580645161290322, 0.36842105263157893),
#  ('Justice Department',
#   'voter suppression',
#   0.22580645161290322,
#   0.30434782608695654),
#  ('Justice Department', 'U.S. Supreme Court', 0.22580645161290322, 0.25),
#  ('Justice Department',
#   'federal government',
#   0.22580645161290322,
#   0.36842105263157893),
#  ('Election Day', 'voter ID law', 0.22222222222222221, 0.35897435897435898),
#  ('Election Day', 'Brennan Center', 0.22222222222222221, 0.41176470588235292),
#  ('Election Day', 'minority voters', 0.22222222222222221, 0.51851851851851849),
#  ('driver\xe2\x80\x99s license',
#   'photo identification',
#   0.23076923076923078,
#   0.22222222222222221),
#  ('photo identification',
#   'voter registration card',
#   0.22222222222222221,
#   0.33333333333333331),
#  ('minority voters', 'early voting', 0.22222222222222221, 0.23999999999999999),
#  ('minority voters', 'election day', 0.22222222222222221, 0.23999999999999999),
#  ('minority voters', 'ballot box', 0.22222222222222221, 0.29999999999999999),
#  ('provisional ballots', 'new law', 0.2857142857142857, 0.22222222222222221),
#  ('election officials', 'new law', 0.23076923076923078, 0.22222222222222221),
#  ('early voting', 'new law', 0.23999999999999999, 0.22222222222222221),
#  ('new law', 'election day', 0.22222222222222221, 0.23999999999999999),
#  ('new law',
#   'voter registration card',
#   0.22222222222222221,
#   0.33333333333333331),
#  ('general election',
#   'voter registration card',
#   0.44444444444444442,
#   0.22222222222222221),
#  ('poll worker',
#   'voter registration card',
#   0.22222222222222221,
#   0.22222222222222221),
#  ('other states',
#   'voter registration card',
#   0.23529411764705882,
#   0.22222222222222221),
#  ('voter registration card',
#   'African Americans',
#   0.22222222222222221,
#   0.2857142857142857),
#  ('North Carolina',
#   'Justice Department',
#   0.22033898305084745,
#   0.41935483870967744),
#  ('voter suppression',
#   'black voters',
#   0.21739130434782608,
#   0.26315789473684209),
#  ('voter suppression',
#   'midterm elections',
#   0.21739130434782608,
#   0.23809523809523808),
#  ('voter fraud', 'absentee ballots', 0.21621621621621623, 1.0),
#  ('provisional ballot',
#   'U.S. Supreme Court',
#   0.21428571428571427,
#   0.21428571428571427),
#  ('provisional ballot',
#   'voter registration card',
#   0.21428571428571427,
#   0.33333333333333331),
#  ('provisional ballot',
#   'new voter ID law',
#   0.21428571428571427,
#   0.35294117647058826),
#  ('driver\xe2\x80\x99s license',
#   'United States',
#   0.23076923076923078,
#   0.21428571428571427),
#  ('United States',
#   'federal government',
#   0.21428571428571427,
#   0.31578947368421051),
#  ('United States', 'voter registration', 0.21428571428571427, 0.375),
#  ('early voting',
#   'U.S. Supreme Court',
#   0.23999999999999999,
#   0.21428571428571427),
#  ('U.S. Supreme Court', 'ID law', 0.21428571428571427, 0.25),
#  ('U.S. Supreme Court',
#   'poll worker',
#   0.21428571428571427,
#   0.33333333333333331),
#  ('U.S. Supreme Court',
#   'federal government',
#   0.21428571428571427,
#   0.31578947368421051),
#  ('U.S. Supreme Court',
#   'voter registration card',
#   0.21428571428571427,
#   0.33333333333333331),
#  ('U.S. Supreme Court',
#   'ballot box',
#   0.21428571428571427,
#   0.29999999999999999),
#  ('photo ID', 'birth certificate', 0.21212121212121213, 0.45161290322580644),
#  ('photo ID', 'voter ID', 0.21212121212121213, 0.36842105263157893),
#  ('photo ID', 'polling place', 0.21212121212121213, 0.41176470588235292),
#  ('photo ID',
#   'driver\xe2\x80\x99s license',
#   0.21212121212121213,
#   0.53846153846153844),
#  ('photo ID',
#   'photo identification',
#   0.21212121212121213,
#   0.51851851851851849),
#  ('photo ID', 'first time', 0.21212121212121213, 0.48275862068965519),
#  ('provisional ballot', 'voter ID', 0.2857142857142857, 0.21052631578947367),
#  ('Voting Rights Act',
#   'voting rights',
#   0.21052631578947367,
#   0.22857142857142856),
#  ('Voting Rights Act', 'new law', 0.21052631578947367, 0.29629629629629628),
#  ('Voting Rights Act',
#   'voter registration card',
#   0.21052631578947367,
#   0.44444444444444442),
#  ('Voting Rights Act', 'absentee ballots', 0.21052631578947367, 0.5),
#  ('Voting Rights Act',
#   'new voter ID law',
#   0.21052631578947367,
#   0.47058823529411764),
#  ('voter ID', 'first time', 0.21052631578947367, 0.27586206896551724),
#  ('voter ID', 'new law', 0.21052631578947367, 0.29629629629629628),
#  ('voter ID', 'U.S. Supreme Court', 0.21052631578947367, 0.2857142857142857),
#  ('ID laws', 'other states', 0.21052631578947367, 0.23529411764705882),
#  ('federal government',
#   'voter registration card',
#   0.21052631578947367,
#   0.22222222222222221),
#  ('federal government',
#   'President Obama',
#   0.21052631578947367,
#   0.22222222222222221),
#  ('federal government',
#   'new voter ID law',
#   0.21052631578947367,
#   0.23529411764705882),
#  ('black voters',
#   'new voter ID law',
#   0.21052631578947367,
#   0.23529411764705882),
#  ('Supreme Court',
#   'provisional ballots',
#   0.20833333333333334,
#   0.47619047619047616),
#  ('Supreme Court', 'early voting', 0.20833333333333334, 0.40000000000000002),
#  ('Supreme Court', 'new law', 0.20833333333333334, 0.37037037037037035),
#  ('Supreme Court',
#   'federal government',
#   0.20833333333333334,
#   0.52631578947368418),
#  ('Supreme Court', 'other states', 0.20833333333333334, 0.58823529411764708),
#  ('Supreme Court', 'ballot box', 0.20833333333333334, 0.5),
#  ('ID law', 'ballot box', 0.20833333333333334, 0.25),
#  ('ID law', 'new voter ID law', 0.20833333333333334, 0.29411764705882354),
#  ('first time', 'poll worker', 0.20689655172413793, 0.33333333333333331),
#  ('first time', 'other states', 0.20689655172413793, 0.35294117647058826),
#  ('first time', 'African Americans', 0.20689655172413793, 0.42857142857142855),
#  ('Election Day',
#   'provisional ballot',
#   0.20634920634920634,
#   0.4642857142857143),
#  ('Election Day', 'early voting', 0.20634920634920634, 0.52000000000000002),
#  ('poll workers', 'new law', 0.20588235294117646, 0.25925925925925924),
#  ('poll workers', 'election day', 0.20588235294117646, 0.28000000000000003),
#  ('poll workers',
#   'new voter ID law',
#   0.20588235294117646,
#   0.41176470588235292),
#  ('polling place',
#   'provisional ballots',
#   0.20588235294117646,
#   0.33333333333333331),
#  ('polling place', 'voter registration', 0.20588235294117646, 0.4375),
#  ('driver\xe2\x80\x99s license',
#   'Brennan Center',
#   0.26923076923076922,
#   0.20588235294117646),
#  ('Brennan Center', 'ID law', 0.20588235294117646, 0.29166666666666669),
#  ('Brennan Center',
#   'new voter ID law',
#   0.20588235294117646,
#   0.41176470588235292),
#  ('voter ID law',
#   'driver\xe2\x80\x99s license',
#   0.20512820512820512,
#   0.30769230769230771),
#  ('voter ID law',
#   'Justice Department',
#   0.20512820512820512,
#   0.25806451612903225),
#  ('voter ID law', 'voting rights', 0.20512820512820512, 0.22857142857142856),
#  ('voter ID law',
#   'photo identification',
#   0.20512820512820512,
#   0.29629629629629628),
#  ('voter ID law', 'Brennan Center', 0.20512820512820512, 0.23529411764705882),
#  ('voter ID law', 'first time', 0.20512820512820512, 0.27586206896551724),
#  ('voter ID law', 'poll worker', 0.20512820512820512, 0.44444444444444442),
#  ('voter ID law', 'ballot box', 0.20512820512820512, 0.40000000000000002),
#  ('voter ID laws',
#   'minority voters',
#   0.20338983050847459,
#   0.44444444444444442),
#  ('North Carolina',
#   'minority voters',
#   0.20338983050847459,
#   0.44444444444444442),
#  ('North Carolina',
#   'U.S. Supreme Court',
#   0.20338983050847459,
#   0.42857142857142855),
#  ('voter fraud', 'voter ID', 0.20270270270270271, 0.39473684210526316),
#  ('voter fraud',
#   'Justice Department',
#   0.20270270270270271,
#   0.4838709677419355),
#  ('voter fraud', 'black voters', 0.20270270270270271, 0.78947368421052633),
#  ('provisional ballot', 'voting rights', 0.25, 0.20000000000000001),
#  ('voting rights',
#   'minority voters',
#   0.20000000000000001,
#   0.25925925925925924),
#  ('voting rights',
#   'election officials',
#   0.20000000000000001,
#   0.26923076923076922),
#  ('voting rights', 'U.S. Supreme Court', 0.20000000000000001, 0.25),
#  ('voting rights', 'African Americans', 0.20000000000000001, 0.5),
#  ('voting rights', 'voter registration', 0.20000000000000001, 0.4375),
#  ('provisional ballots',
#   'election day',
#   0.23809523809523808,
#   0.20000000000000001),
#  ('early voting', 'election day', 0.20000000000000001, 0.20000000000000001),
#  ('early voting', 'eligible voters', 0.20000000000000001, 0.23809523809523808),
#  ('early voting',
#   'same-day registration',
#   0.20000000000000001,
#   0.35714285714285715),
#  ('early voting', 'black voters', 0.20000000000000001, 0.26315789473684209),
#  ('early voting',
#   'midterm elections',
#   0.20000000000000001,
#   0.23809523809523808),
#  ('election day',
#   'voter registration card',
#   0.20000000000000001,
#   0.27777777777777779),
#  ('poll worker', 'ballot box', 0.22222222222222221, 0.20000000000000001),
#  ('voter registration card',
#   'ballot box',
#   0.22222222222222221,
#   0.20000000000000001),
#  ('photo ID', 'U.S. Supreme Court', 0.19696969696969696, 0.4642857142857143),
#  ('photo ID', 'ID law', 0.19696969696969696, 0.54166666666666663),
#  ('birth certificate',
#   'Justice Department',
#   0.19354838709677419,
#   0.19354838709677419),
#  ('birth certificate',
#   'election officials',
#   0.19354838709677419,
#   0.23076923076923078),
#  ('birth certificate', 'voter registration', 0.19354838709677419, 0.375),
#  ('Justice Department',
#   'United States',
#   0.19354838709677419,
#   0.21428571428571427),
#  ('Justice Department',
#   'eligible voters',
#   0.19354838709677419,
#   0.2857142857142857),
#  ('driver\xe2\x80\x99s license',
#   'provisional ballots',
#   0.19230769230769232,
#   0.23809523809523808),
#  ('driver\xe2\x80\x99s license',
#   'ID law',
#   0.19230769230769232,
#   0.20833333333333334),
#  ('driver\xe2\x80\x99s license',
#   'federal government',
#   0.19230769230769232,
#   0.26315789473684209),
#  ('driver\xe2\x80\x99s license',
#   'Voter ID laws',
#   0.19230769230769232,
#   0.22727272727272727),
#  ('driver\xe2\x80\x99s license',
#   'voter registration',
#   0.19230769230769232,
#   0.3125),
#  ('election officials', 'ID law', 0.19230769230769232, 0.20833333333333334),
#  ('election officials',
#   'poll worker',
#   0.19230769230769232,
#   0.27777777777777779),
#  ('Election Day', 'Supreme Court', 0.19047619047619047, 0.25),
#  ('Election Day',
#   'driver\xe2\x80\x99s license',
#   0.19047619047619047,
#   0.46153846153846156),
#  ('Election Day',
#   'election officials',
#   0.19047619047619047,
#   0.46153846153846156),
#  ('provisional ballots',
#   'general election',
#   0.19047619047619047,
#   0.44444444444444442),
#  ('provisional ballots',
#   'black voters',
#   0.19047619047619047,
#   0.21052631578947367),
#  ('provisional ballots',
#   'ballot box',
#   0.19047619047619047,
#   0.20000000000000001),
#  ('provisional ballots',
#   'African Americans',
#   0.19047619047619047,
#   0.2857142857142857),
#  ('provisional ballots', 'voter registration', 0.19047619047619047, 0.25),
#  ('eligible voters',
#   'midterm elections',
#   0.19047619047619047,
#   0.19047619047619047),
#  ('midterm elections',
#   'President Obama',
#   0.19047619047619047,
#   0.22222222222222221),
#  ('midterm elections',
#   'new voter ID law',
#   0.19047619047619047,
#   0.23529411764705882),
#  ('midterm elections',
#   'African Americans',
#   0.19047619047619047,
#   0.2857142857142857),
#  ('voter fraud', 'provisional ballot', 0.1891891891891892, 0.5),
#  ('voter fraud',
#   'election officials',
#   0.1891891891891892,
#   0.53846153846153844),
#  ('Supreme Court', 'provisional ballot', 0.1875, 0.32142857142857145),
#  ('Supreme Court', 'poll workers', 0.1875, 0.26470588235294118),
#  ('Supreme Court', 'U.S. Supreme Court', 0.1875, 0.32142857142857145),
#  ('Supreme Court', 'ID laws', 0.1875, 0.47368421052631576),
#  ('Supreme Court', 'voter registration card', 0.1875, 0.5),
#  ('general election', 'absentee ballots', 0.33333333333333331, 0.1875),
#  ('same-day registration', 'voter registration', 0.21428571428571427, 0.1875),
#  ('voter ID laws',
#   'Voting Rights Act',
#   0.1864406779661017,
#   0.28947368421052633),
#  ('voter ID laws', 'poll workers', 0.1864406779661017, 0.3235294117647059),
#  ('voter ID laws', 'Brennan Center', 0.1864406779661017, 0.3235294117647059),
#  ('North Carolina', 'voter ID law', 0.1864406779661017, 0.28205128205128205),
#  ('North Carolina',
#   'provisional ballots',
#   0.1864406779661017,
#   0.52380952380952384),
#  ('North Carolina', 'early voting', 0.1864406779661017, 0.44),
#  ('North Carolina',
#   'midterm elections',
#   0.1864406779661017,
#   0.52380952380952384),
#  ('photo identification',
#   'election officials',
#   0.18518518518518517,
#   0.19230769230769232),
#  ('photo identification', 'ID law', 0.18518518518518517, 0.20833333333333334),
#  ('photo identification',
#   'midterm elections',
#   0.18518518518518517,
#   0.23809523809523808),
#  ('photo identification',
#   'new voter ID law',
#   0.18518518518518517,
#   0.29411764705882354),
#  ('photo identification', 'voter registration', 0.18518518518518517, 0.3125),
#  ('minority voters',
#   'provisional ballots',
#   0.18518518518518517,
#   0.23809523809523808),
#  ('minority voters',
#   'election officials',
#   0.18518518518518517,
#   0.19230769230769232),
#  ('minority voters', 'ID law', 0.18518518518518517, 0.20833333333333334),
#  ('minority voters', 'ID laws', 0.18518518518518517, 0.26315789473684209),
#  ('minority voters',
#   'new voter ID law',
#   0.18518518518518517,
#   0.29411764705882354),
#  ('new law', 'midterm elections', 0.18518518518518517, 0.23809523809523808),
#  ('new law', 'African Americans', 0.18518518518518517, 0.35714285714285715),
#  ('provisional ballot', 'Voting Rights Act', 0.25, 0.18421052631578946),
#  ('Voting Rights Act', 'poll worker', 0.18421052631578946, 0.3888888888888889),
#  ('Voting Rights Act',
#   'other states',
#   0.18421052631578946,
#   0.41176470588235292),
#  ('voter ID',
#   'photo identification',
#   0.18421052631578946,
#   0.25925925925925924),
#  ('voter ID', 'early voting', 0.18421052631578946, 0.28000000000000003),
#  ('voter ID', 'Voter ID laws', 0.18421052631578946, 0.31818181818181818),
#  ('photo ID', 'voting rights', 0.18181818181818182, 0.34285714285714286),
#  ('photo ID', 'election officials', 0.18181818181818182, 0.46153846153846156),
#  ('poll worker', 'Voter ID laws', 0.22222222222222221, 0.18181818181818182),
#  ('eligible voters',
#   'Voter ID laws',
#   0.19047619047619047,
#   0.18181818181818182),
#  ('ID laws', 'Voter ID laws', 0.21052631578947367, 0.18181818181818182),
#  ('black voters', 'Voter ID laws', 0.21052631578947367, 0.18181818181818182),
#  ('Voter ID laws', 'ballot box', 0.18181818181818182, 0.20000000000000001),
#  ('federal elections', 'full article', 0.18181818181818182, 0.25),
#  ('voter ID law', 'United States', 0.17948717948717949, 0.25),
#  ('voter ID law',
#   'provisional ballots',
#   0.17948717948717949,
#   0.33333333333333331),
#  ('voter ID law',
#   'election officials',
#   0.17948717948717949,
#   0.26923076923076922),
#  ('voter ID law', 'early voting', 0.17948717948717949, 0.28000000000000003),
#  ('provisional ballot',
#   'United States',
#   0.17857142857142858,
#   0.17857142857142858),
#  ('provisional ballot',
#   'minority voters',
#   0.17857142857142858,
#   0.18518518518518517),
#  ('provisional ballot',
#   'election day',
#   0.17857142857142858,
#   0.20000000000000001),
#  ('provisional ballot', 'ID laws', 0.17857142857142858, 0.26315789473684209),
#  ('provisional ballot',
#   'midterm elections',
#   0.17857142857142858,
#   0.23809523809523808),
#  ('photo identification',
#   'United States',
#   0.18518518518518517,
#   0.17857142857142858),
#  ('United States',
#   'minority voters',
#   0.17857142857142858,
#   0.18518518518518517),
#  ('United States', 'other states', 0.17857142857142858, 0.29411764705882354),
#  ('provisional ballots',
#   'U.S. Supreme Court',
#   0.23809523809523808,
#   0.17857142857142858),
#  ('new law', 'U.S. Supreme Court', 0.18518518518518517, 0.17857142857142858),
#  ('U.S. Supreme Court',
#   'eligible voters',
#   0.17857142857142858,
#   0.23809523809523808),
#  ('U.S. Supreme Court', 'voter registration', 0.17857142857142858, 0.3125),
#  ('birth certificate',
#   'polling place',
#   0.19354838709677419,
#   0.17647058823529413),
#  ('poll workers', 'voter registration', 0.17647058823529413, 0.375),
#  ('polling place', 'United States', 0.17647058823529413, 0.21428571428571427),
#  ('polling place',
#   'minority voters',
#   0.17647058823529413,
#   0.22222222222222221),
#  ('polling place',
#   'U.S. Supreme Court',
#   0.17647058823529413,
#   0.21428571428571427),
#  ('polling place',
#   'voter registration card',
#   0.17647058823529413,
#   0.33333333333333331),
#  ('Brennan Center', 'poll worker', 0.17647058823529413, 0.33333333333333331),
#  ('Brennan Center', 'other states', 0.17647058823529413, 0.35294117647058826),
#  ('new voter ID law',
#   'African Americans',
#   0.17647058823529413,
#   0.21428571428571427),
#  ('new voter ID law', 'voter registration', 0.17647058823529413, 0.1875),
#  ('voter fraud', 'polling place', 0.17567567567567569, 0.38235294117647056),
#  ('Election Day',
#   'Voting Rights Act',
#   0.17460317460317459,
#   0.28947368421052633),
#  ('Election Day', 'voter ID', 0.17460317460317459, 0.28947368421052633),
#  ('Election Day', 'new law', 0.17460317460317459, 0.40740740740740738),
#  ('voter suppression', 'absentee ballots', 0.17391304347826086, 0.25),
#  ('first time', 'election day', 0.17241379310344829, 0.20000000000000001),
#  ('first time', 'ID laws', 0.17241379310344829, 0.26315789473684209),
#  ('first time', 'black voters', 0.17241379310344829, 0.26315789473684209),
#  ('first time', 'midterm elections', 0.17241379310344829, 0.23809523809523808),
#  ('first time', 'ballot box', 0.17241379310344829, 0.25),
#  ('first time', 'voter registration', 0.17241379310344829, 0.3125),
#  ('polling place', 'voting rights', 0.17647058823529413, 0.17142857142857143),
#  ('Justice Department',
#   'voting rights',
#   0.19354838709677419,
#   0.17142857142857143),
#  ('voting rights', 'early voting', 0.17142857142857143, 0.23999999999999999),
#  ('voter ID laws', 'voting rights', 0.16949152542372881, 0.2857142857142857),
#  ('voter ID laws',
#   'U.S. Supreme Court',
#   0.16949152542372881,
#   0.35714285714285715),
#  ('voter ID laws', 'ID laws', 0.16949152542372881, 0.52631578947368418),
#  ('North Carolina',
#   'provisional ballot',
#   0.16949152542372881,
#   0.35714285714285715),
#  ('North Carolina', 'poll workers', 0.16949152542372881, 0.29411764705882354),
#  ('North Carolina',
#   'photo identification',
#   0.16949152542372881,
#   0.37037037037037035),
#  ('North Carolina', 'United States', 0.16949152542372881, 0.35714285714285715),
#  ('photo ID', 'provisional ballot', 0.16666666666666666, 0.39285714285714285),
#  ('photo ID', 'Brennan Center', 0.16666666666666666, 0.3235294117647059),
#  ('photo ID', 'minority voters', 0.16666666666666666, 0.40740740740740738),
#  ('photo ID', 'early voting', 0.16666666666666666, 0.44),
#  ('Supreme Court',
#   'Justice Department',
#   0.16666666666666666,
#   0.25806451612903225),
#  ('Supreme Court',
#   'photo identification',
#   0.16666666666666666,
#   0.29629629629629628),
#  ('Supreme Court', 'United States', 0.16666666666666666, 0.2857142857142857),
#  ('Supreme Court', 'election day', 0.16666666666666666, 0.32000000000000001),
#  ('Supreme Court', 'Voter ID laws', 0.16666666666666666, 0.36363636363636365),
#  ('ID law', 'poll worker', 0.16666666666666666, 0.22222222222222221),
#  ('ID law', 'other states', 0.16666666666666666, 0.23529411764705882),
#  ('ID law', 'Voter ID laws', 0.16666666666666666, 0.18181818181818182),
#  ('ID law', 'absentee ballots', 0.16666666666666666, 0.25),
#  ('ID law', 'African Americans', 0.16666666666666666, 0.2857142857142857),
#  ('ID law', 'voter registration', 0.16666666666666666, 0.25),
#  ('poll worker', 'new voter ID law', 0.16666666666666666, 0.17647058823529413),
#  ('President Obama',
#   'new voter ID law',
#   0.16666666666666666,
#   0.17647058823529413),
#  ('President Obama',
#   'African Americans',
#   0.16666666666666666,
#   0.21428571428571427),
#  ('voter fraud',
#   'driver\xe2\x80\x99s license',
#   0.16216216216216217,
#   0.46153846153846156),
#  ('voter fraud', 'voting rights', 0.16216216216216217, 0.34285714285714286),
#  ('voter fraud',
#   'provisional ballots',
#   0.16216216216216217,
#   0.5714285714285714),
#  ('voter fraud', 'early voting', 0.16216216216216217, 0.47999999999999998),
#  ('voter fraud', 'election day', 0.16216216216216217, 0.47999999999999998),
#  ('birth certificate',
#   'poll worker',
#   0.16129032258064516,
#   0.27777777777777779),
#  ('birth certificate',
#   'eligible voters',
#   0.16129032258064516,
#   0.23809523809523808),
#  ('birth certificate',
#   'federal government',
#   0.16129032258064516,
#   0.26315789473684209),
#  ('birth certificate',
#   'midterm elections',
#   0.16129032258064516,
#   0.23809523809523808),
#  ('birth certificate',
#   'other states',
#   0.16129032258064516,
#   0.29411764705882354),
#  ('birth certificate',
#   'federal elections',
#   0.16129032258064516,
#   0.45454545454545453),
#  ('Justice Department', 'ballot box', 0.16129032258064516, 0.25),
#  ('Justice Department',
#   'President Obama',
#   0.16129032258064516,
#   0.27777777777777779),
#  ('early voting', 'poll worker', 0.16, 0.22222222222222221),
#  ('early voting', 'new voter ID law', 0.16, 0.23529411764705882),
#  ('election day', 'new voter ID law', 0.16, 0.23529411764705882),
#  ('Election Day',
#   'birth certificate',
#   0.15873015873015872,
#   0.32258064516129031),
#  ('Election Day',
#   'provisional ballots',
#   0.15873015873015872,
#   0.47619047619047616),
#  ('Election Day', 'ID law', 0.15873015873015872, 0.41666666666666669),
#  ('Voting Rights Act', 'voter ID', 0.15789473684210525, 0.15789473684210525),
#  ('Voting Rights Act',
#   'driver\xe2\x80\x99s license',
#   0.15789473684210525,
#   0.23076923076923078),
#  ('Voting Rights Act',
#   'United States',
#   0.15789473684210525,
#   0.21428571428571427),
#  ('Voting Rights Act',
#   'election officials',
#   0.15789473684210525,
#   0.23076923076923078),
#  ('Voting Rights Act', 'ID law', 0.15789473684210525, 0.25),
#  ('Voting Rights Act',
#   'African Americans',
#   0.15789473684210525,
#   0.42857142857142855),
#  ('Voting Rights Act', 'voter registration', 0.15789473684210525, 0.375),
#  ('poll workers', 'voter ID', 0.17647058823529413, 0.15789473684210525),
#  ('voter ID',
#   'driver\xe2\x80\x99s license',
#   0.15789473684210525,
#   0.23076923076923078),
#  ('voter ID', 'Justice Department', 0.15789473684210525, 0.19354838709677419),
#  ('voter ID', 'United States', 0.15789473684210525, 0.21428571428571427),
#  ('voter ID', 'provisional ballots', 0.15789473684210525, 0.2857142857142857),
#  ('voter ID', 'election officials', 0.15789473684210525, 0.23076923076923078),
#  ('voter ID', 'ID laws', 0.15789473684210525, 0.31578947368421051),
#  ('voter ID',
#   'voter registration card',
#   0.15789473684210525,
#   0.33333333333333331),
#  ('general election',
#   'federal government',
#   0.33333333333333331,
#   0.15789473684210525),
#  ('poll worker', 'ID laws', 0.16666666666666666, 0.15789473684210525),
#  ('ID laws', 'voter registration', 0.15789473684210525, 0.1875),
#  ('federal government',
#   'federal elections',
#   0.15789473684210525,
#   0.27272727272727271),
#  ('federal government', 'voter registration', 0.15789473684210525, 0.1875),
#  ('black voters', 'President Obama', 0.15789473684210525, 0.16666666666666666),
#  ('voter ID law',
#   'federal government',
#   0.15384615384615385,
#   0.31578947368421051),
#  ('voter ID law',
#   'new voter ID law',
#   0.15384615384615385,
#   0.35294117647058826),
#  ('voter ID law', 'voter registration', 0.15384615384615385, 0.375),
#  ('driver\xe2\x80\x99s license',
#   'election officials',
#   0.15384615384615385,
#   0.15384615384615385),
#  ('election officials', 'early voting', 0.15384615384615385, 0.16),
#  ('election officials',
#   'federal government',
#   0.15384615384615385,
#   0.21052631578947367),
#  ('election officials',
#   'new voter ID law',
#   0.15384615384615385,
#   0.23529411764705882),
#  ('voter ID laws', 'polling place', 0.15254237288135594, 0.26470588235294118),
#  ('voter ID laws',
#   'driver\xe2\x80\x99s license',
#   0.15254237288135594,
#   0.34615384615384615),
#  ('voter ID laws', 'United States', 0.15254237288135594, 0.32142857142857145),
#  ('voter ID laws', 'first time', 0.15254237288135594, 0.31034482758620691),
#  ('voter ID laws',
#   'election officials',
#   0.15254237288135594,
#   0.34615384615384615),
#  ('voter ID laws', 'ID law', 0.15254237288135594, 0.375),
#  ('voter ID laws',
#   'eligible voters',
#   0.15254237288135594,
#   0.42857142857142855),
#  ('North Carolina', 'polling place', 0.15254237288135594, 0.26470588235294118),
#  ('North Carolina',
#   'election officials',
#   0.15254237288135594,
#   0.34615384615384615),
#  ('North Carolina', 'new law', 0.15254237288135594, 0.33333333333333331),
#  ('North Carolina', 'ID law', 0.15254237288135594, 0.375),
#  ('North Carolina',
#   'federal government',
#   0.15254237288135594,
#   0.47368421052631576),
#  ('North Carolina', 'ballot box', 0.15254237288135594, 0.45000000000000001),
#  ('North Carolina', 'President Obama', 0.15254237288135594, 0.5),
#  ('photo ID', 'United States', 0.15151515151515152, 0.35714285714285715),
#  ('photo ID', 'provisional ballots', 0.15151515151515152, 0.47619047619047616),
#  ('photo ID', 'poll worker', 0.15151515151515152, 0.55555555555555558),
#  ('photo ID', 'black voters', 0.15151515151515152, 0.52631578947368418),
#  ('photo ID', 'Voter ID laws', 0.15151515151515152, 0.45454545454545453),
#  ('ballot box', 'voter registration', 0.14999999999999999, 0.1875),
#  ('voter fraud',
#   'U.S. Supreme Court',
#   0.14864864864864866,
#   0.39285714285714285),
#  ('voter fraud', 'ID law', 0.14864864864864866, 0.45833333333333331),
#  ('voter fraud', 'ID laws', 0.14864864864864866, 0.57894736842105265),
#  ('voter fraud', 'Voter ID laws', 0.14864864864864866, 0.5),
#  ('voter fraud', 'ballot box', 0.14864864864864866, 0.55000000000000004),
#  ('driver\xe2\x80\x99s license',
#   'minority voters',
#   0.15384615384615385,
#   0.14814814814814814),
#  ('photo identification',
#   'voter suppression',
#   0.14814814814814814,
#   0.17391304347826086),
#  ('photo identification',
#   'same-day registration',
#   0.14814814814814814,
#   0.2857142857142857),
#  ('photo identification',
#   'federal government',
#   0.14814814814814814,
#   0.21052631578947367),
#  ('minority voters',
#   'general election',
#   0.14814814814814814,
#   0.44444444444444442),
#  ('minority voters',
#   'same-day registration',
#   0.14814814814814814,
#   0.2857142857142857),
#  ('minority voters', 'black voters', 0.14814814814814814, 0.21052631578947367),
#  ('minority voters', 'other states', 0.14814814814814814, 0.23529411764705882),
#  ('minority voters',
#   'African Americans',
#   0.14814814814814814,
#   0.2857142857142857),
#  ('minority voters', 'voter registration', 0.14814814814814814, 0.25),
#  ('new law', 'general election', 0.14814814814814814, 0.44444444444444442),
#  ('new law', 'ID laws', 0.14814814814814814, 0.21052631578947367),
#  ('poll workers', 'United States', 0.14705882352941177, 0.17857142857142858),
#  ('poll workers',
#   'same-day registration',
#   0.14705882352941177,
#   0.35714285714285715),
#  ('poll workers', 'other states', 0.14705882352941177, 0.29411764705882354),
#  ('polling place', 'Brennan Center', 0.14705882352941177, 0.14705882352941177),
#  ('polling place', 'early voting', 0.14705882352941177, 0.20000000000000001),
#  ('polling place', 'new law', 0.14705882352941177, 0.18518518518518517),
#  ('polling place',
#   'federal government',
#   0.14705882352941177,
#   0.26315789473684209),
#  ('polling place', 'Voter ID laws', 0.14705882352941177, 0.22727272727272727),
#  ('polling place',
#   'new voter ID law',
#   0.14705882352941177,
#   0.29411764705882354),
#  ('Justice Department',
#   'Brennan Center',
#   0.16129032258064516,
#   0.14705882352941177),
#  ('Brennan Center', 'ID laws', 0.14705882352941177, 0.26315789473684209),
#  ('Brennan Center',
#   'federal government',
#   0.14705882352941177,
#   0.26315789473684209),
#  ('Supreme Court',
#   'driver\xe2\x80\x99s license',
#   0.14583333333333334,
#   0.26923076923076922),
#  ('Supreme Court',
#   'voter suppression',
#   0.14583333333333334,
#   0.30434782608695654),
#  ('Supreme Court',
#   'midterm elections',
#   0.14583333333333334,
#   0.33333333333333331),
#  ('Supreme Court',
#   'new voter ID law',
#   0.14583333333333334,
#   0.41176470588235292),
#  ('Supreme Court', 'African Americans', 0.14583333333333334, 0.5),
#  ('Supreme Court', 'voter registration', 0.14583333333333334, 0.4375),
#  ('Election Day',
#   'federal government',
#   0.14285714285714285,
#   0.47368421052631576),
#  ('provisional ballot',
#   'federal government',
#   0.14285714285714285,
#   0.21052631578947367),
#  ('provisional ballot',
#   'black voters',
#   0.14285714285714285,
#   0.21052631578947367),
#  ('provisional ballot',
#   'ballot box',
#   0.14285714285714285,
#   0.20000000000000001),
#  ('provisional ballot',
#   'African Americans',
#   0.14285714285714285,
#   0.2857142857142857),
#  ('provisional ballot', 'voter registration', 0.14285714285714285, 0.25),
#  ('driver\xe2\x80\x99s license',
#   'voting rights',
#   0.19230769230769232,
#   0.14285714285714285),
#  ('voting rights',
#   'provisional ballots',
#   0.14285714285714285,
#   0.23809523809523808),
#  ('voting rights', 'new law', 0.14285714285714285, 0.18518518518518517),
#  ('voting rights', 'election day', 0.14285714285714285, 0.20000000000000001),
#  ('voting rights',
#   'same-day registration',
#   0.14285714285714285,
#   0.35714285714285715),
#  ('voting rights', 'black voters', 0.14285714285714285, 0.26315789473684209),
#  ('photo identification',
#   'U.S. Supreme Court',
#   0.14814814814814814,
#   0.14285714285714285),
#  ('United States',
#   'election officials',
#   0.14285714285714285,
#   0.15384615384615385),
#  ('United States', 'election day', 0.14285714285714285, 0.16),
#  ('United States',
#   'U.S. Supreme Court',
#   0.14285714285714285,
#   0.14285714285714285),
#  ('United States', 'ID law', 0.14285714285714285, 0.16666666666666666),
#  ('United States',
#   'midterm elections',
#   0.14285714285714285,
#   0.19047619047619047),
#  ('United States',
#   'voter registration card',
#   0.14285714285714285,
#   0.22222222222222221),
#  ('United States',
#   'President Obama',
#   0.14285714285714285,
#   0.22222222222222221),
#  ('United States',
#   'new voter ID law',
#   0.14285714285714285,
#   0.23529411764705882),
#  ('provisional ballots',
#   'poll worker',
#   0.14285714285714285,
#   0.16666666666666666),
#  ('provisional ballots', 'ID laws', 0.14285714285714285, 0.15789473684210525),
#  ('provisional ballots', 'absentee ballots', 0.14285714285714285, 0.1875),
#  ('provisional ballots', 'full article', 0.14285714285714285, 0.375),
#  ('election day', 'U.S. Supreme Court', 0.16, 0.14285714285714285),
#  ('U.S. Supreme Court', 'ID laws', 0.14285714285714285, 0.21052631578947367),
#  ('U.S. Supreme Court',
#   'President Obama',
#   0.14285714285714285,
#   0.22222222222222221),
#  ('U.S. Supreme Court',
#   'federal elections',
#   0.14285714285714285,
#   0.36363636363636365),
#  ('U.S. Supreme Court',
#   'new voter ID law',
#   0.14285714285714285,
#   0.23529411764705882),
#  ('general election',
#   'African Americans',
#   0.22222222222222221,
#   0.14285714285714285),
#  ('eligible voters', 'ID laws', 0.14285714285714285, 0.15789473684210525),
#  ('eligible voters',
#   'new voter ID law',
#   0.14285714285714285,
#   0.17647058823529413),
#  ('eligible voters',
#   'African Americans',
#   0.14285714285714285,
#   0.21428571428571427),
#  ('same-day registration',
#   'federal elections',
#   0.14285714285714285,
#   0.18181818181818182),
#  ('same-day registration',
#   'African Americans',
#   0.14285714285714285,
# ...
#   0.095238095238095233,
#   0.42857142857142855),
#  ('Election Day', 'ID laws', 0.095238095238095233, 0.31578947368421051),
#  ('Election Day', 'black voters', 0.095238095238095233, 0.31578947368421051),
#  ('Election Day', 'other states', 0.095238095238095233, 0.35294117647058826),
#  ('Election Day',
#   'President Obama',
#   0.095238095238095233,
#   0.33333333333333331),
#  ('provisional ballots',
#   'eligible voters',
#   0.095238095238095233,
#   0.095238095238095233),
#  ('provisional ballots',
#   'federal government',
#   0.095238095238095233,
#   0.10526315789473684),
#  ('provisional ballots',
#   'other states',
#   0.095238095238095233,
#   0.11764705882352941),
#  ('provisional ballots',
#   'President Obama',
#   0.095238095238095233,
#   0.1111111111111111),
#  ('eligible voters',
#   'same-day registration',
#   0.095238095238095233,
#   0.14285714285714285),
#  ('eligible voters',
#   'voter registration card',
#   0.095238095238095233,
#   0.1111111111111111),
#  ('eligible voters',
#   'President Obama',
#   0.095238095238095233,
#   0.1111111111111111),
#  ('eligible voters', 'voter registration', 0.095238095238095233, 0.125),
#  ('same-day registration',
#   'midterm elections',
#   0.14285714285714285,
#   0.095238095238095233),
#  ('federal government',
#   'midterm elections',
#   0.10526315789473684,
#   0.095238095238095233),
#  ('midterm elections',
#   'ballot box',
#   0.095238095238095233,
#   0.10000000000000001),
#  ('midterm elections', 'voter registration', 0.095238095238095233, 0.125),
#  ('voter fraud', 'African Americans', 0.0945945945945946, 0.5),
#  ('voter fraud', 'voter registration', 0.0945945945945946, 0.4375),
#  ('photo ID', 'voter suppression', 0.090909090909090912, 0.2608695652173913),
#  ('photo ID', 'ID laws', 0.090909090909090912, 0.31578947368421051),
#  ('photo ID', 'new voter ID law', 0.090909090909090912, 0.35294117647058826),
#  ('general election',
#   'federal elections',
#   0.1111111111111111,
#   0.090909090909090912),
#  ('federal government',
#   'Voter ID laws',
#   0.10526315789473684,
#   0.090909090909090912),
#  ('other states', 'Voter ID laws', 0.11764705882352941, 0.090909090909090912),
#  ('voter registration card',
#   'Voter ID laws',
#   0.1111111111111111,
#   0.090909090909090912),
#  ('Voter ID laws',
#   'President Obama',
#   0.090909090909090912,
#   0.1111111111111111),
#  ('Voter ID laws', 'full article', 0.090909090909090912, 0.25),
#  ('poll workers',
#   'general election',
#   0.088235294117647065,
#   0.33333333333333331),
#  ('poll workers',
#   'federal government',
#   0.088235294117647065,
#   0.15789473684210525),
#  ('poll workers', 'ballot box', 0.088235294117647065, 0.14999999999999999),
#  ('poll workers', 'absentee ballots', 0.088235294117647065, 0.1875),
#  ('poll workers',
#   'federal elections',
#   0.088235294117647065,
#   0.27272727272727271),
#  ('poll workers',
#   'African Americans',
#   0.088235294117647065,
#   0.21428571428571427),
#  ('polling place',
#   'eligible voters',
#   0.088235294117647065,
#   0.14285714285714285),
#  ('polling place',
#   'same-day registration',
#   0.088235294117647065,
#   0.21428571428571427),
#  ('polling place', 'black voters', 0.088235294117647065, 0.15789473684210525),
#  ('polling place', 'other states', 0.088235294117647065, 0.17647058823529413),
#  ('polling place',
#   'President Obama',
#   0.088235294117647065,
#   0.16666666666666666),
#  ('Brennan Center',
#   'voter suppression',
#   0.088235294117647065,
#   0.13043478260869565),
#  ('Brennan Center', 'election day', 0.088235294117647065, 0.12),
#  ('Brennan Center', 'black voters', 0.088235294117647065, 0.15789473684210525),
#  ('Brennan Center',
#   'midterm elections',
#   0.088235294117647065,
#   0.14285714285714285),
#  ('Brennan Center', 'absentee ballots', 0.088235294117647065, 0.1875),
#  ('voter suppression',
#   'eligible voters',
#   0.086956521739130432,
#   0.095238095238095233),
#  ('voter suppression',
#   'federal government',
#   0.086956521739130432,
#   0.10526315789473684),
#  ('voter suppression',
#   'ballot box',
#   0.086956521739130432,
#   0.10000000000000001),
#  ('voter suppression',
#   'new voter ID law',
#   0.086956521739130432,
#   0.11764705882352941),
#  ('voting rights',
#   'eligible voters',
#   0.085714285714285715,
#   0.14285714285714285),
#  ('voting rights',
#   'federal government',
#   0.085714285714285715,
#   0.15789473684210525),
#  ('voting rights', 'other states', 0.085714285714285715, 0.17647058823529413),
#  ('voting rights', 'Voter ID laws', 0.085714285714285715, 0.13636363636363635),
#  ('voting rights',
#   'President Obama',
#   0.085714285714285715,
#   0.16666666666666666),
#  ('voting rights',
#   'federal elections',
#   0.085714285714285715,
#   0.27272727272727271),
#  ('voter ID laws',
#   'African Americans',
#   0.084745762711864403,
#   0.35714285714285715),
#  ('voter ID laws', 'voter registration', 0.084745762711864403, 0.3125),
#  ('North Carolina', 'election day', 0.084745762711864403, 0.20000000000000001),
#  ('North Carolina', 'White House', 0.084745762711864403, 0.55555555555555558),
#  ('North Carolina', 'voter registration', 0.084745762711864403, 0.3125),
#  ('Supreme Court',
#   'President Obama',
#   0.083333333333333329,
#   0.22222222222222221),
#  ('voter suppression', 'ID law', 0.086956521739130432, 0.083333333333333329),
#  ('ID law',
#   'same-day registration',
#   0.083333333333333329,
#   0.14285714285714285),
#  ('ID law', 'black voters', 0.083333333333333329, 0.10526315789473684),
#  ('ID law', 'midterm elections', 0.083333333333333329, 0.095238095238095233),
#  ('ID law', 'federal elections', 0.083333333333333329, 0.18181818181818182),
#  ('ID law', 'full article', 0.083333333333333329, 0.25),
#  ('voter fraud', 'poll worker', 0.081081081081081086, 0.33333333333333331),
#  ('voter fraud',
#   'voter registration card',
#   0.081081081081081086,
#   0.33333333333333331),
#  ('voter fraud',
#   'new voter ID law',
#   0.081081081081081086,
#   0.35294117647058826),
#  ('voter suppression',
#   'early voting',
#   0.086956521739130432,
#   0.080000000000000002),
#  ('early voting',
#   'general election',
#   0.080000000000000002,
#   0.22222222222222221),
#  ('early voting', 'ID laws', 0.080000000000000002, 0.10526315789473684),
#  ('election day', 'poll worker', 0.080000000000000002, 0.1111111111111111),
#  ('election day',
#   'same-day registration',
#   0.080000000000000002,
#   0.14285714285714285),
#  ('election day',
#   'midterm elections',
#   0.080000000000000002,
#   0.095238095238095233),
#  ('Election Day', 'Voter ID laws', 0.079365079365079361, 0.22727272727272727),
#  ('Election Day', 'voter registration', 0.079365079365079361, 0.3125),
#  ('Voting Rights Act',
#   'same-day registration',
#   0.078947368421052627,
#   0.21428571428571427),
#  ('Voting Rights Act',
#   'midterm elections',
#   0.078947368421052627,
#   0.14285714285714285),
#  ('Voting Rights Act',
#   'Voter ID laws',
#   0.078947368421052627,
#   0.13636363636363635),
#  ('Voting Rights Act',
#   'President Obama',
#   0.078947368421052627,
#   0.16666666666666666),
#  ('voter ID', 'other states', 0.078947368421052627, 0.17647058823529413),
#  ('voter ID', 'voter registration', 0.078947368421052627, 0.1875),
#  ('voter ID law',
#   'federal elections',
#   0.076923076923076927,
#   0.27272727272727271),
#  ('driver\xe2\x80\x99s license',
#   'eligible voters',
#   0.076923076923076927,
#   0.095238095238095233),
#  ('driver\xe2\x80\x99s license',
#   'black voters',
#   0.076923076923076927,
#   0.10526315789473684),
#  ('driver\xe2\x80\x99s license',
#   'midterm elections',
#   0.076923076923076927,
#   0.095238095238095233),
#  ('driver\xe2\x80\x99s license',
#   'other states',
#   0.076923076923076927,
#   0.11764705882352941),
#  ('driver\xe2\x80\x99s license',
#   'President Obama',
#   0.076923076923076927,
#   0.1111111111111111),
#  ('driver\xe2\x80\x99s license',
#   'absentee ballots',
#   0.076923076923076927,
#   0.125),
#  ('driver\xe2\x80\x99s license',
#   'African Americans',
#   0.076923076923076927,
#   0.14285714285714285),
#  ('election officials',
#   'election day',
#   0.076923076923076927,
#   0.080000000000000002),
#  ('election officials',
#   'eligible voters',
#   0.076923076923076927,
#   0.095238095238095233),
#  ('photo ID',
#   'same-day registration',
#   0.07575757575757576,
#   0.35714285714285715),
#  ('photo ID', 'midterm elections', 0.07575757575757576, 0.23809523809523808),
#  ('photo identification',
#   'poll worker',
#   0.07407407407407407,
#   0.1111111111111111),
#  ('photo identification',
#   'ballot box',
#   0.07407407407407407,
#   0.10000000000000001),
#  ('photo identification',
#   'federal elections',
#   0.07407407407407407,
#   0.18181818181818182),
#  ('minority voters',
#   'voter suppression',
#   0.07407407407407407,
#   0.086956521739130432),
#  ('minority voters', 'poll worker', 0.07407407407407407, 0.1111111111111111),
#  ('minority voters',
#   'Voter ID laws',
#   0.07407407407407407,
#   0.090909090909090912),
#  ('minority voters',
#   'President Obama',
#   0.07407407407407407,
#   0.1111111111111111),
#  ('minority voters', 'absentee ballots', 0.07407407407407407, 0.125),
#  ('voter suppression', 'new law', 0.086956521739130432, 0.07407407407407407),
#  ('new law', 'poll worker', 0.07407407407407407, 0.1111111111111111),
#  ('new law', 'federal elections', 0.07407407407407407, 0.18181818181818182),
#  ('new law', 'voter registration', 0.07407407407407407, 0.125),
#  ('provisional ballot',
#   'general election',
#   0.071428571428571425,
#   0.22222222222222221),
#  ('provisional ballot',
#   'President Obama',
#   0.071428571428571425,
#   0.1111111111111111),
#  ('provisional ballot', 'absentee ballots', 0.071428571428571425, 0.125),
#  ('provisional ballot',
#   'federal elections',
#   0.071428571428571425,
#   0.18181818181818182),
#  ('provisional ballot', 'full article', 0.071428571428571425, 0.25),
#  ('GREG PALAST', 'African Americans', 1.0, 0.071428571428571425),
#  ('United States', 'early voting', 0.071428571428571425, 0.080000000000000002),
#  ('United States',
#   'general election',
#   0.071428571428571425,
#   0.22222222222222221),
#  ('United States', 'ballot box', 0.071428571428571425, 0.10000000000000001),
#  ('United States', 'absentee ballots', 0.071428571428571425, 0.125),
#  ('U.S. Supreme Court',
#   'general election',
#   0.071428571428571425,
#   0.22222222222222221),
#  ('U.S. Supreme Court',
#   'other states',
#   0.071428571428571425,
#   0.11764705882352941),
#  ('U.S. Supreme Court', 'absentee ballots', 0.071428571428571425, 0.125),
#  ('general election',
#   'same-day registration',
#   0.1111111111111111,
#   0.071428571428571425),
#  ('same-day registration', 'full article', 0.071428571428571425, 0.125),
#  ('White House',
#   'African Americans',
#   0.1111111111111111,
#   0.071428571428571425),
#  ('federal elections',
#   'African Americans',
#   0.090909090909090912,
#   0.071428571428571425),
#  ('African Americans', 'full article', 0.071428571428571425, 0.125),
#  ('first time', 'general election', 0.068965517241379309, 0.22222222222222221),
#  ('first time', 'absentee ballots', 0.068965517241379309, 0.125),
#  ('voter ID laws', 'election day', 0.067796610169491525, 0.16),
#  ('voter ID laws',
#   'same-day registration',
#   0.067796610169491525,
#   0.2857142857142857),
#  ('voter ID laws',
#   'federal government',
#   0.067796610169491525,
#   0.21052631578947367),
#  ('voter ID laws',
#   'President Obama',
#   0.067796610169491525,
#   0.22222222222222221),
#  ('voter ID laws', 'absentee ballots', 0.067796610169491525, 0.25),
#  ('voter fraud',
#   'general election',
#   0.067567567567567571,
#   0.55555555555555558),
#  ('voter fraud',
#   'same-day registration',
#   0.067567567567567571,
#   0.35714285714285715),
#  ('voter fraud', 'other states', 0.067567567567567571, 0.29411764705882354),
#  ('birth certificate',
#   'general election',
#   0.064516129032258063,
#   0.22222222222222221),
#  ('birth certificate', 'absentee ballots', 0.064516129032258063, 0.125),
#  ('birth certificate', 'full article', 0.064516129032258063, 0.25),
#  ('provisional ballot',
#   'Justice Department',
#   0.071428571428571425,
#   0.064516129032258063),
#  ('Justice Department',
#   'provisional ballots',
#   0.064516129032258063,
#   0.095238095238095233),
#  ('Justice Department',
#   'general election',
#   0.064516129032258063,
#   0.22222222222222221),
#  ('Justice Department',
#   'poll worker',
#   0.064516129032258063,
#   0.1111111111111111),
#  ('Justice Department',
#   'same-day registration',
#   0.064516129032258063,
#   0.14285714285714285),
#  ('Justice Department',
#   'midterm elections',
#   0.064516129032258063,
#   0.095238095238095233),
#  ('Justice Department',
#   'voter registration card',
#   0.064516129032258063,
#   0.1111111111111111),
#  ('Justice Department',
#   'Voter ID laws',
#   0.064516129032258063,
#   0.090909090909090912),
#  ('Election Day', 'absentee ballots', 0.063492063492063489, 0.25),
#  ('Election Day',
#   'African Americans',
#   0.063492063492063489,
#   0.2857142857142857),
#  ('general election', 'voter registration', 0.1111111111111111, 0.0625),
#  ('absentee ballots', 'federal elections', 0.0625, 0.090909090909090912),
#  ('absentee ballots', 'African Americans', 0.0625, 0.071428571428571425),
#  ('absentee ballots', 'full article', 0.0625, 0.125),
#  ('absentee ballots', 'voter registration', 0.0625, 0.0625),
#  ('photo ID', 'general election', 0.060606060606060608, 0.44444444444444442),
#  ('photo ID', 'federal elections', 0.060606060606060608, 0.36363636363636365),
#  ('poll workers',
#   'voter suppression',
#   0.058823529411764705,
#   0.086956521739130432),
#  ('poll workers',
#   'eligible voters',
#   0.058823529411764705,
#   0.095238095238095233),
#  ('poll workers', 'black voters', 0.058823529411764705, 0.10526315789473684),
#  ('poll workers',
#   'midterm elections',
#   0.058823529411764705,
#   0.095238095238095233),
#  ('poll workers', 'President Obama', 0.058823529411764705, 0.1111111111111111),
#  ('polling place',
#   'voter suppression',
#   0.058823529411764705,
#   0.086956521739130432),
#  ('polling place', 'absentee ballots', 0.058823529411764705, 0.125),
#  ('polling place',
#   'federal elections',
#   0.058823529411764705,
#   0.18181818181818182),
#  ('polling place',
#   'African Americans',
#   0.058823529411764705,
#   0.14285714285714285),
#  ('polling place', 'full article', 0.058823529411764705, 0.25),
#  ('GREG PALAST', 'new voter ID law', 1.0, 0.058823529411764705),
#  ('Brennan Center',
#   'general election',
#   0.058823529411764705,
#   0.22222222222222221),
#  ('Brennan Center',
#   'Voter ID laws',
#   0.058823529411764705,
#   0.090909090909090912),
#  ('Brennan Center', 'ballot box', 0.058823529411764705, 0.10000000000000001),
#  ('Brennan Center',
#   'federal elections',
#   0.058823529411764705,
#   0.18181818181818182),
#  ('general election',
#   'new voter ID law',
#   0.1111111111111111,
#   0.058823529411764705),
#  ('same-day registration',
#   'other states',
#   0.071428571428571425,
#   0.058823529411764705),
#  ('other states', 'absentee ballots', 0.058823529411764705, 0.0625),
#  ('other states',
#   'African Americans',
#   0.058823529411764705,
#   0.071428571428571425),
#  ('absentee ballots', 'new voter ID law', 0.0625, 0.058823529411764705),
#  ('voting rights',
#   'general election',
#   0.057142857142857141,
#   0.22222222222222221),
#  ('voting rights', 'poll worker', 0.057142857142857141, 0.1111111111111111),
#  ('voting rights',
#   'midterm elections',
#   0.057142857142857141,
#   0.095238095238095233),
#  ('voting rights',
#   'voter registration card',
#   0.057142857142857141,
#   0.1111111111111111),
#  ('voting rights', 'absentee ballots', 0.057142857142857141, 0.125),
#  ('GREG PALAST', 'President Obama', 1.0, 0.055555555555555552),
#  ('general election', 'poll worker', 0.1111111111111111, 0.055555555555555552),
#  ('poll worker',
#   'same-day registration',
#   0.055555555555555552,
#   0.071428571428571425),
#  ('poll worker',
#   'President Obama',
#   0.055555555555555552,
#   0.055555555555555552),
#  ('poll worker', 'absentee ballots', 0.055555555555555552, 0.0625),
#  ('poll worker',
#   'federal elections',
#   0.055555555555555552,
#   0.090909090909090912),
#  ('poll worker',
#   'African Americans',
#   0.055555555555555552,
#   0.071428571428571425),
#  ('same-day registration',
#   'voter registration card',
#   0.071428571428571425,
#   0.055555555555555552),
#  ('same-day registration',
#   'President Obama',
#   0.071428571428571425,
#   0.055555555555555552),
#  ('voter registration card',
#   'President Obama',
#   0.055555555555555552,
#   0.055555555555555552),
#  ('voter registration card', 'full article', 0.055555555555555552, 0.125),
#  ...]

# %%
term_groups = {}
groups=[]
for r in relationships:
    if r[0] not in term_groups.keys() and r[1] not in term_groups.keys():
        g = len(groups)
        groups.append([r[0], r[1]])
        term_groups[r[0]]=g
        term_groups[r[1]]=g
    elif r[0] not in term_groups.keys():
        groups[term_groups[r[1]]].append(r[0])
        term_groups[r[0]]=term_groups[r[1]]
    elif r[1] not in term_groups.keys():
        groups[term_groups[r[0]]].append(r[1])
        term_groups[r[1]]=term_groups[r[0]]
    else:
        continue

# %%
groups
# Out:
# [['Supreme Court',
#   'Voting Rights Act',
#   'Justice Department',
#   'voter ID law',
#   'voter ID',
#   'ID law',
#   'voting rights'],
#  ['first time',
#   'new law',
#   'Brennan Center',
#   'minority voters',
#   'U.S. Supreme Court',
#   'election officials',
#   'same-day registration',
#   'United States'],
#  ['photo ID', 'Election Day', 'voter fraud'],
#  ['provisional ballot',
#   'poll workers',
#   'polling place',
#   'provisional ballots',
#   'birth certificate',
#   'midterm elections',
#   'White House'],
#  ['photo identification', 'election day', 'voter suppression'],
#  ['voter ID laws', 'North Carolina'],
#  ['voter registration card',
#   'new voter ID law',
#   'voter registration',
#   'general election'],
#  ['driver\xe2\x80\x99s license',
#   'early voting',
#   'poll worker',
#   'Voter ID laws'],
#  ['federal government', 'other states', 'President Obama'],
#  ['black voters', 'absentee ballots', 'eligible voters'],
#  ['ID laws', 'ballot box', 'African Americans', 'GREG PALAST'],
#  ['federal elections', 'full article']]

# %%
overlap_freqs['group']=pd.Series(term_groups)

# %%
pd.Series(term_groups)
# Out:
# African Americans          10
# Brennan Center              1
# Election Day                2
# GREG PALAST                10
# ID law                      0
# ID laws                    10
# Justice Department          0
# North Carolina              5
# President Obama             8
# Supreme Court               0
# U.S. Supreme Court          1
# United States               1
# Voter ID laws               7
# Voting Rights Act           0
# White House                 3
# absentee ballots            9
# ballot box                 10
# birth certificate           3
# black voters                9
# driver’s license            7
# early voting                7
# election day                4
# election officials          1
# eligible voters             9
# federal elections          11
# federal government          8
# first time                  1
# full article               11
# general election            6
# midterm elections           3
# minority voters             1
# new law                     1
# new voter ID law            6
# other states                8
# photo ID                    2
# photo identification        4
# poll worker                 7
# poll workers                3
# polling place               3
# provisional ballot          3
# provisional ballots         3
# same-day registration       1
# voter ID                    0
# voter ID law                0
# voter ID laws               5
# voter fraud                 2
# voter registration          6
# voter registration card     6
# voter suppression           4
# voting rights               0
# dtype: int64

# %%
overlap_freqs[['group']]
# Out:
#                          group
# voter fraud                  2
# photo ID                     2
# voter ID laws                5
# North Carolina               5
# Election Day                 2
# Supreme Court                0
# birth certificate            3
# provisional ballot           3
# voter ID law                 0
# Voting Rights Act            0
# poll workers                 3
# voter ID                     0
# polling place                3
# driver’s license             7
# Justice Department           0
# voting rights                0
# GREG PALAST                 10
# photo identification         4
# Brennan Center               1
# United States                1
# first time                   1
# minority voters              1
# provisional ballots          3
# election officials           1
# voter suppression            4
# early voting                 7
# new law                      1
# election day                 4
# U.S. Supreme Court           1
# ID law                       0
# general election             6
# poll worker                  7
# eligible voters              9
# same-day registration        1
# ID laws                     10
# federal government           8
# black voters                 9
# midterm elections            3
# other states                 8
# voter registration card      6
# Voter ID laws                7
# ballot box                  10
# President Obama              8
# absentee ballots             9
# White House                  3
# federal elections           11
# new voter ID law             6
# African Americans           10
# full article                11
# voter registration           6

# %%
column_order=[t for g in groups for t in g]

# %%
column_order
# Out:
# ['Supreme Court',
#  'Voting Rights Act',
#  'Justice Department',
#  'voter ID law',
#  'voter ID',
#  'ID law',
#  'voting rights',
#  'first time',
#  'new law',
#  'Brennan Center',
#  'minority voters',
#  'U.S. Supreme Court',
#  'election officials',
#  'same-day registration',
#  'United States',
#  'photo ID',
#  'Election Day',
#  'voter fraud',
#  'provisional ballot',
#  'poll workers',
#  'polling place',
#  'provisional ballots',
#  'birth certificate',
#  'midterm elections',
#  'White House',
#  'photo identification',
#  'election day',
#  'voter suppression',
#  'voter ID laws',
#  'North Carolina',
#  'voter registration card',
#  'new voter ID law',
#  'voter registration',
#  'general election',
#  'driver\xe2\x80\x99s license',
#  'early voting',
#  'poll worker',
#  'Voter ID laws',
#  'federal government',
#  'other states',
#  'President Obama',
#  'black voters',
#  'absentee ballots',
#  'eligible voters',
#  'ID laws',
#  'ballot box',
#  'African Americans',
#  'GREG PALAST',
#  'federal elections',
#  'full article']

# %%
overlap_freqs['ordering']=pd.Series(pd.Series({k:v for v,k in enumerate(column_order)}))

# %%
overlap_freqs.sort('ordering', inplace=True)
show = ['group']+column_order
overlap_freqs[show]
# Out:
#                          group  Supreme Court  Voting Rights Act  \
# Supreme Court                0       1.000000           0.479167
# Voting Rights Act            0       0.605263           1.000000
# Justice Department           0       0.258065           0.548387
# voter ID law                 0       0.512821           0.358974
# voter ID                     0       0.342105           0.157895
# ID law                       0       0.541667           0.250000
# voting rights                0       0.371429           0.228571
# first time                   1       0.448276           0.413793
# new law                      1       0.370370           0.296296
# Brennan Center               1       0.382353           0.382353
# minority voters              1       0.444444           0.370370
# U.S. Supreme Court           1       0.321429           0.428571
# election officials           1       0.192308           0.230769
# same-day registration        1       0.357143           0.214286
# United States                1       0.285714           0.214286
# photo ID                     2       0.242424           0.227273
# Election Day                 2       0.190476           0.174603
# voter fraud                  2       0.243243           0.243243
# provisional ballot           3       0.321429           0.250000
# poll workers                 3       0.264706           0.264706
# polling place                3       0.176471           0.117647
# provisional ballots          3       0.476190           0.238095
# birth certificate            3       0.419355           0.354839
# midterm elections            3       0.333333           0.142857
# White House                  3       0.000000           0.000000
# photo identification         4       0.296296           0.407407
# election day                 4       0.320000           0.520000
# voter suppression            4       0.304348           0.391304
# voter ID laws                5       0.288136           0.186441
# North Carolina               5       0.338983           0.271186
# voter registration card      6       0.500000           0.444444
# new voter ID law             6       0.411765           0.470588
# voter registration           6       0.437500           0.375000
# general election             6       0.555556           0.222222
# driver’s license             7       0.269231           0.230769
# early voting                 7       0.400000           0.360000
# poll worker                  7       0.277778           0.388889
# Voter ID laws                7       0.363636           0.136364
# federal government           8       0.526316           0.473684
# other states                 8       0.588235           0.411765
# President Obama              8       0.222222           0.166667
# black voters                 9       0.263158           0.578947
# absentee ballots             9       0.125000           0.500000
# eligible voters              9       0.238095           0.238095
# ID laws                     10       0.473684           0.263158
# ballot box                  10       0.500000           0.450000
# African Americans           10       0.500000           0.428571
# GREG PALAST                 10       0.000000           0.000000
# federal elections           11       0.545455           0.454545
# full article                11       0.250000           0.125000
#
#                          Justice Department  voter ID law  voter ID    ID law  \
# Supreme Court                      0.166667      0.416667  0.270833  0.270833
# Voting Rights Act                  0.447368      0.368421  0.157895  0.157895
# Justice Department                 1.000000      0.258065  0.193548  0.129032
# voter ID law                       0.205128      1.000000  0.358974  0.333333
# voter ID                           0.157895      0.368421  1.000000  0.289474
# ID law                             0.166667      0.541667  0.458333  1.000000
# voting rights                      0.171429      0.228571  0.342857  0.257143
# first time                         0.103448      0.275862  0.275862  0.275862
# new law                            0.148148      0.444444  0.296296  0.296296
# Brennan Center                     0.147059      0.235294  0.323529  0.205882
# minority voters                    0.296296      0.481481  0.333333  0.185185
# U.S. Supreme Court                 0.250000      0.392857  0.285714  0.214286
# election officials                 0.153846      0.269231  0.230769  0.192308
# same-day registration              0.142857      0.142857  0.142857  0.142857
# United States                      0.214286      0.250000  0.214286  0.142857
# photo ID                           0.136364      0.287879  0.212121  0.196970
# Election Day                       0.095238      0.222222  0.174603  0.158730
# voter fraud                        0.202703      0.243243  0.202703  0.148649
# provisional ballot                 0.071429      0.428571  0.285714  0.285714
# poll workers                       0.029412      0.352941  0.176471  0.264706
# polling place                      0.117647      0.294118  0.264706  0.264706
# provisional ballots                0.095238      0.333333  0.285714  0.380952
# birth certificate                  0.193548      0.387097  0.290323  0.258065
# midterm elections                  0.095238      0.238095  0.095238  0.095238
# White House                        0.111111      0.000000  0.000000  0.000000
# photo identification               0.296296      0.296296  0.259259  0.185185
# election day                       0.320000      0.200000  0.200000  0.120000
# voter suppression                  0.304348      0.173913  0.217391  0.086957
# voter ID laws                      0.118644      0.271186  0.271186  0.152542
# North Carolina                     0.220339      0.186441  0.237288  0.152542
# voter registration card            0.111111      0.500000  0.333333  0.333333
# new voter ID law                   0.235294      0.352941  0.117647  0.294118
# voter registration                 0.187500      0.375000  0.187500  0.250000
# general election                   0.222222      0.444444  0.444444  0.333333
# driver’s license                   0.115385      0.307692  0.230769  0.192308
# early voting                       0.120000      0.280000  0.280000  0.280000
# poll worker                        0.111111      0.444444  0.277778  0.222222
# Voter ID laws                      0.090909      0.227273  0.318182  0.181818
# federal government                 0.368421      0.315789  0.263158  0.157895
# other states                       0.235294      0.529412  0.176471  0.235294
# President Obama                    0.277778      0.055556  0.111111  0.055556
# black voters                       0.526316      0.210526  0.210526  0.105263
# absentee ballots                   0.562500      0.250000  0.250000  0.250000
# eligible voters                    0.285714      0.238095  0.238095  0.047619
# ID laws                            0.157895      0.526316  0.315789  0.368421
# ballot box                         0.250000      0.400000  0.500000  0.250000
# African Americans                  0.285714      0.285714  0.357143  0.285714
# GREG PALAST                        0.000000      0.000000  0.000000  0.000000
# federal elections                  0.272727      0.272727  0.181818  0.181818
# full article                       0.125000      0.250000  0.125000  0.250000
#
#                          voting rights  first time   new law      ...       \
# Supreme Court                 0.270833    0.270833  0.208333      ...
# Voting Rights Act             0.210526    0.315789  0.210526      ...
# Justice Department            0.193548    0.096774  0.129032      ...
# voter ID law                  0.205128    0.205128  0.307692      ...
# voter ID                      0.315789    0.210526  0.210526      ...
# ID law                        0.375000    0.333333  0.333333      ...
# voting rights                 1.000000    0.228571  0.142857      ...
# first time                    0.275862    1.000000  0.448276      ...
# new law                       0.185185    0.481481  1.000000      ...
# Brennan Center                0.323529    0.441176  0.264706      ...
# minority voters               0.259259    0.296296  0.370370      ...
# U.S. Supreme Court            0.250000    0.285714  0.178571      ...
# election officials            0.269231    0.269231  0.230769      ...
# same-day registration         0.357143    0.285714  0.071429      ...
# United States                 0.285714    0.142857  0.250000      ...
# photo ID                      0.181818    0.212121  0.136364      ...
# Election Day                  0.238095    0.269841  0.174603      ...
# voter fraud                   0.162162    0.108108  0.135135      ...
# provisional ballot            0.250000    0.321429  0.321429      ...
# poll workers                  0.117647    0.264706  0.205882      ...
# polling place                 0.176471    0.264706  0.147059      ...
# provisional ballots           0.238095    0.380952  0.285714      ...
# birth certificate             0.290323    0.322581  0.354839      ...
# midterm elections             0.095238    0.238095  0.238095      ...
# White House                   0.000000    0.111111  0.111111      ...
# photo identification          0.148148    0.296296  0.333333      ...
# election day                  0.200000    0.200000  0.240000      ...
# voter suppression             0.173913    0.130435  0.086957      ...
# voter ID laws                 0.169492    0.152542  0.101695      ...
# North Carolina                0.254237    0.237288  0.152542      ...
# voter registration card       0.111111    0.555556  0.333333      ...
# new voter ID law              0.235294    0.529412  0.411765      ...
# voter registration            0.437500    0.312500  0.125000      ...
# general election              0.222222    0.222222  0.444444      ...
# driver’s license              0.192308    0.307692  0.115385      ...
# early voting                  0.240000    0.320000  0.240000      ...
# poll worker                   0.111111    0.333333  0.111111      ...
# Voter ID laws                 0.136364    0.045455  0.000000      ...
# federal government            0.157895    0.368421  0.368421      ...
# other states                  0.176471    0.352941  0.470588      ...
# President Obama               0.166667    0.166667  0.055556      ...
# black voters                  0.263158    0.263158  0.157895      ...
# absentee ballots              0.125000    0.125000  0.187500      ...
# eligible voters               0.142857    0.142857  0.142857      ...
# ID laws                       0.210526    0.263158  0.210526      ...
# ballot box                    0.200000    0.250000  0.150000      ...
# African Americans             0.500000    0.428571  0.357143      ...
# GREG PALAST                   1.000000    1.000000  0.000000      ...
# federal elections             0.272727    0.272727  0.181818      ...
# full article                  0.125000    0.125000  0.125000      ...
#
#                          President Obama  black voters  absentee ballots  \
# Supreme Court                   0.083333      0.104167          0.041667
# Voting Rights Act               0.078947      0.289474          0.210526
# Justice Department              0.161290      0.322581          0.290323
# voter ID law                    0.025641      0.102564          0.102564
# voter ID                        0.052632      0.105263          0.105263
# ID law                          0.041667      0.083333          0.166667
# voting rights                   0.085714      0.142857          0.057143
# first time                      0.103448      0.172414          0.068966
# new law                         0.037037      0.111111          0.111111
# Brennan Center                  0.029412      0.088235          0.088235
# minority voters                 0.074074      0.148148          0.074074
# U.S. Supreme Court              0.142857      0.107143          0.071429
# election officials              0.000000      0.038462          0.230769
# same-day registration           0.071429      0.142857          0.142857
# United States                   0.142857      0.107143          0.071429
# photo ID                        0.045455      0.151515          0.106061
# Election Day                    0.095238      0.095238          0.063492
# voter fraud                     0.040541      0.202703          0.216216
# provisional ballot              0.071429      0.142857          0.071429
# poll workers                    0.058824      0.058824          0.088235
# polling place                   0.088235      0.088235          0.058824
# provisional ballots             0.095238      0.190476          0.142857
# birth certificate               0.032258      0.096774          0.064516
# midterm elections               0.190476      0.238095          0.000000
# White House                     0.222222      0.000000          0.000000
# photo identification            0.037037      0.333333          0.333333
# election day                    0.040000      0.320000          0.280000
# voter suppression               0.130435      0.217391          0.173913
# voter ID laws                   0.067797      0.118644          0.067797
# North Carolina                  0.152542      0.101695          0.050847
# voter registration card         0.055556      0.111111          0.111111
# new voter ID law                0.176471      0.235294          0.058824
# voter registration              0.062500      0.125000          0.062500
# general election                0.000000      0.111111          0.333333
# driver’s license                0.076923      0.076923          0.076923
# early voting                    0.120000      0.200000          0.120000
# poll worker                     0.055556      0.055556          0.055556
# Voter ID laws                   0.090909      0.181818          0.045455
# federal government              0.210526      0.000000          0.105263
# other states                    0.000000      0.117647          0.058824
# President Obama                 1.000000      0.166667          0.000000
# black voters                    0.157895      1.000000          0.368421
# absentee ballots                0.000000      0.437500          1.000000
# eligible voters                 0.095238      0.333333          0.047619
# ID laws                         0.105263      0.105263          0.105263
# ballot box                      0.050000      0.250000          0.100000
# African Americans               0.214286      0.357143          0.071429
# GREG PALAST                     1.000000      1.000000          0.000000
# federal elections               0.090909      0.000000          0.090909
# full article                    0.000000      0.000000          0.125000
#
#                          eligible voters   ID laws  ballot box  \
# Supreme Court                   0.104167  0.187500    0.208333
# Voting Rights Act               0.131579  0.131579    0.236842
# Justice Department              0.193548  0.096774    0.161290
# voter ID law                    0.128205  0.256410    0.205128
# voter ID                        0.131579  0.157895    0.263158
# ID law                          0.041667  0.291667    0.208333
# voting rights                   0.085714  0.114286    0.114286
# first time                      0.103448  0.172414    0.172414
# new law                         0.111111  0.148148    0.111111
# Brennan Center                  0.117647  0.147059    0.058824
# minority voters                 0.296296  0.185185    0.222222
# U.S. Supreme Court              0.178571  0.142857    0.214286
# election officials              0.076923  0.115385    0.115385
# same-day registration           0.142857  0.071429    0.000000
# United States                   0.107143  0.107143    0.071429
# photo ID                        0.136364  0.090909    0.121212
# Election Day                    0.126984  0.095238    0.126984
# voter fraud                     0.135135  0.148649    0.148649
# provisional ballot              0.107143  0.178571    0.142857
# poll workers                    0.058824  0.117647    0.088235
# polling place                   0.088235  0.117647    0.117647
# provisional ballots             0.095238  0.142857    0.190476
# birth certificate               0.161290  0.225806    0.129032
# midterm elections               0.190476  0.047619    0.095238
# White House                     0.000000  0.111111    0.111111
# photo identification            0.111111  0.111111    0.074074
# election day                    0.040000  0.000000    0.120000
# voter suppression               0.086957  0.000000    0.086957
# voter ID laws                   0.152542  0.169492    0.118644
# North Carolina                  0.118644  0.135593    0.152542
# voter registration card         0.111111  0.277778    0.222222
# new voter ID law                0.176471  0.058824    0.058824
# voter registration              0.125000  0.187500    0.187500
# general election                0.111111  0.111111    0.222222
# driver’s license                0.076923  0.230769    0.115385
# early voting                    0.200000  0.080000    0.120000
# poll worker                     0.055556  0.166667    0.222222
# Voter ID laws                   0.181818  0.181818    0.181818
# federal government              0.052632  0.052632    0.052632
# other states                    0.058824  0.235294    0.117647
# President Obama                 0.111111  0.111111    0.055556
# black voters                    0.368421  0.105263    0.263158
# absentee ballots                0.062500  0.125000    0.125000
# eligible voters                 1.000000  0.142857    0.285714
# ID laws                         0.157895  1.000000    0.368421
# ballot box                      0.300000  0.350000    1.000000
# African Americans               0.214286  0.357143    0.428571
# GREG PALAST                     1.000000  0.000000    0.000000
# federal elections               0.000000  0.000000    0.181818
# full article                    0.000000  0.000000    0.000000
#
#                          African Americans  GREG PALAST  federal elections  \
# Supreme Court                     0.145833     0.000000           0.125000
# Voting Rights Act                 0.157895     0.000000           0.131579
# Justice Department                0.129032     0.000000           0.096774
# voter ID law                      0.102564     0.000000           0.076923
# voter ID                          0.131579     0.000000           0.052632
# ID law                            0.166667     0.000000           0.083333
# voting rights                     0.200000     0.028571           0.085714
# first time                        0.206897     0.034483           0.103448
# new law                           0.185185     0.000000           0.074074
# Brennan Center                    0.029412     0.000000           0.058824
# minority voters                   0.148148     0.000000           0.111111
# U.S. Supreme Court                0.107143     0.000000           0.142857
# election officials                0.038462     0.000000           0.038462
# same-day registration             0.142857     0.000000           0.142857
# United States                     0.107143     0.000000           0.107143
# photo ID                          0.045455     0.000000           0.060606
# Election Day                      0.063492     0.015873           0.047619
# voter fraud                       0.094595     0.013514           0.040541
# provisional ballot                0.142857     0.035714           0.071429
# poll workers                      0.088235     0.000000           0.088235
# polling place                     0.058824     0.000000           0.058824
# provisional ballots               0.190476     0.047619           0.047619
# birth certificate                 0.129032     0.000000           0.161290
# midterm elections                 0.190476     0.047619           0.000000
# White House                       0.111111     0.000000           0.000000
# photo identification              0.111111     0.000000           0.074074
# election day                      0.120000     0.000000           0.120000
# voter suppression                 0.130435     0.043478           0.043478
# voter ID laws                     0.084746     0.000000           0.033898
# North Carolina                    0.118644     0.016949           0.033898
# voter registration card           0.222222     0.000000           0.111111
# new voter ID law                  0.176471     0.058824           0.117647
# voter registration                0.250000     0.000000           0.125000
# general election                  0.222222     0.000000           0.111111
# driver’s license                  0.076923     0.000000           0.115385
# early voting                      0.120000     0.040000           0.120000
# poll worker                       0.055556     0.000000           0.055556
# Voter ID laws                     0.045455     0.000000           0.000000
# federal government                0.052632     0.000000           0.157895
# other states                      0.058824     0.000000           0.117647
# President Obama                   0.166667     0.055556           0.055556
# black voters                      0.263158     0.052632           0.000000
# absentee ballots                  0.062500     0.000000           0.062500
# eligible voters                   0.142857     0.047619           0.000000
# ID laws                           0.263158     0.000000           0.000000
# ballot box                        0.300000     0.000000           0.100000
# African Americans                 1.000000     0.071429           0.071429
# GREG PALAST                       1.000000     1.000000           0.000000
# federal elections                 0.090909     0.000000           1.000000
# full article                      0.125000     0.000000           0.250000
#
#                          full article
# Supreme Court                0.041667
# Voting Rights Act            0.026316
# Justice Department           0.032258
# voter ID law                 0.051282
# voter ID                     0.026316
# ID law                       0.083333
# voting rights                0.028571
# first time                   0.034483
# new law                      0.037037
# Brennan Center               0.029412
# minority voters              0.037037
# U.S. Supreme Court           0.035714
# election officials           0.038462
# same-day registration        0.071429
# United States                0.000000
# photo ID                     0.045455
# Election Day                 0.015873
# voter fraud                  0.013514
# provisional ballot           0.071429
# poll workers                 0.029412
# polling place                0.058824
# provisional ballots          0.142857
# birth certificate            0.064516
# midterm elections            0.000000
# White House                  0.000000
# photo identification         0.037037
# election day                 0.040000
# voter suppression            0.000000
# voter ID laws                0.050847
# North Carolina               0.033898
# voter registration card      0.055556
# new voter ID law             0.117647
# voter registration           0.000000
# general election             0.111111
# driver’s license             0.038462
# early voting                 0.040000
# poll worker                  0.111111
# Voter ID laws                0.090909
# federal government           0.105263
# other states                 0.117647
# President Obama              0.000000
# black voters                 0.000000
# absentee ballots             0.062500
# eligible voters              0.000000
# ID laws                      0.000000
# ballot box                   0.000000
# African Americans            0.071429
# GREG PALAST                  0.000000
# federal elections            0.181818
# full article                 1.000000
#
# [50 rows x 51 columns]

# %%
show
